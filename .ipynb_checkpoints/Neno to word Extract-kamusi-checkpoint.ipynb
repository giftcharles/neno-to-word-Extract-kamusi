# %%
import re
import pandas as pd
import random

# %%
kamusi_file = "kamusi-swahili-english.txt"

with open(kamusi_file, "r") as f:
    maneno_list = f.read().replace("ã€€","").split("\n")

maneno_list = [re.sub(r"-", "", e) for e in maneno_list if e!="" and len(e) > 1]
len(maneno_list)
# Out:
# 29869

# %%
random.choice(maneno_list)
# Out:
# 'fuatilia (verb applicative), follow carefully. kufuatilia hadithi inayosimuliwa [Muk].'

# %%
neno_lines=[]
for i in maneno_list:
    for l in i.split("."):
        if l!="":
            neno_lines.append(l.split(","))
            
neno_lines
# Out:
# [['a (preposition)', ' of (a + noun used to form possessives)'],
#  [' kitabu cha mwanafunzi'],
#  [" the pupil's book"],
#  ['a (preposition)', ' of (a + noun used to form adjectives)'],
#  [' jambo la ajabu'],
#  [' a surprising thing'],
#  ['a (interjection)', ' expresses joy'],
#  [' a (interjection)', ' expresses pain'],
#  ['a (interjection)', ' expresses surprise'],
#  [' aa (interjection)', ' expresses joy'],
#  ['aa (interjection)', ' expresses pain'],
#  ['aa (interjection)', ' expresses surprise'],
#  [' aali (adjective)', ' excellent'],
#  ['aali (adjective)', ' firstclass'],
#  [' aali (adjective)', ' good'],
#  ['aasi (verb)', ' be disobedient'],
#  ['  [also: asi]'],
#  ['aasi (verb)', ' not meet an obligation'],
#  ['  [also: asi]'],
#  ['aasi (verb)', ' rebel'],
#  [' wameaasia serikali yao'],
#  [' They have rebelled against their government'],
#  [' [also: asi]'],
#  ['aasi (verb)', ' revolt'],
#  ['aasi (noun 5/6)', ' pl maasi', ' rebellion'],
#  [' aasi (noun 5/6)', ' pl maasi', ' revolt'],
#  ['abadan (adverb)', ' never'],
#  [' hawatakuja kwetu abadan'],
#  [' They will never come to us'],
#  ['abadan (interjection)', ' Make way!'],
#  ['abadi (adverb)', ' always'],
#  [' kazi yake ni kuiba abadi'],
#  [' He is always stealing'],
#  [' [rare]'],
#  ['abadi (adverb)', ' constantly'],
#  ['  [rare]'],
#  ['abd (noun 9/10an)', ' pl abd', ' servant'],
#  [' [liter] abd (noun 9/10an)', ' pl abd', ' slave'],
#  [' [liter] Abdallah (noun)', ' Abdullah'],
#  [' [proper name]'],
#  ['abe (interjection)', ' At your service!'],
#  [' (< (formerly used by slaves))'],
#  [' [also: labeka', ' labe', ' bee', ' ebee!]'],
#  ['abe (interjection)', " Yes ma'am!"],
#  [' (< (formerly used by slaves))'],
#  [' abe (interjection)', ' Yes sir!'],
#  [' (< (formerly used by slaves))'],
#  [' abedari (interjection)', ' Look out!'],
#  ['abedari (interjection)', ' Take care!'],
#  ['abedari (interjection)', ' Watch out!'],
#  [' [also: habedari!',
#   ' bedari!] abedari (noun 9/10)',
#   ' pl abedari',
#   ' block (used on dhows)'],
#  [' (< port?)'],
#  [' abedari (noun 9/10)', ' pl abedari', ' pulley (used on dhows)'],
#  [' (< port?)'],
#  [' abee (interjection)', ' at your service'],
#  [' "Tinda!" Tinda alikuwa bintiye'],
#  ['['],
#  ['] "Abee!"  [Kez]'],
#  [' (< Arabic: labeka)'],
#  ['abee (interjection)', ' I am coming'],
#  ['  (< Arabic: labeka)'],
#  ['abee (interjection)', ' Yes sir!'],
#  [' (< Arabic: labeka)'],
#  ['abee (interjection)', " Yes ma'am!"],
#  ['  (< Arabic: labeka)'],
#  ['abidi (adverb)', ' always'],
#  [' kazi yake ni kuiba abidi'],
#  [' He is always stealing'],
#  [' [rare]'],
#  ['abidi (adverb)', ' constantly'],
#  [' [rare] abidi (adverb)', ' rare'],
#  [' [rare]'],
#  ['abiri (verb)', ' cross (river or lake or sea)'],
#  [' abiri (verb)', ' go (i'],
#  ['e'],
#  [' travel as a passenger)'],
#  [' abiri (verb)', ' pass over'],
#  ['abiri (verb)', ' travel (as passenger)'],
#  [' abiri (verb)', ' travel (by sea)'],
#  [' abiria (verb)', ' travel to'],
#  ['abiria (noun 9/10an)', ' pl maabiria', ' passenger'],
#  [' (< abiri vArabic)'],
#  [' abirika (verb)', ' travel'],
#  [' (< abiri)'],
#  ['abirisha (verb)', ' convey (as passenger)'],
#  [' (< abiri V)'],
#  [' abirisha (verb)', ' cause to travel'],
#  [' (< abiri)'],
#  ['abiriwa (verb)', ' be crossed (i'],
#  ['e'],
#  ['  a river)'],
#  ['abiriwa (verb)', ' be passed over (i'],
#  ['e'],
#  [' a geographic entity)'],
#  [' bahari inaabiriwa na ndege mamia kwa siku'],
#  [' the ocean is crossed by hundreds of airplanes each day'],
#  ['abiriwa (verb)', ' be travelled (i'],
#  ['e'],
#  ['  a road)'],
#  [' (< abiri)'],
#  ['abos (interjection)', ' exclamation of admiration'],
#  [' nikae naye hapa hapa duniani', ' aboss [Sul]'],
#  ['abu (noun 9/10an)', ' pl abu', ' father'],
#  [' [liter]'],
#  ['abudi (noun 9/10)', ' pl abudi', ' alternative'],
#  [' hapana abudi'],
#  [' There is no alternative'],
#  [' One must'],
#  ['abudi (noun 9/10)', ' pl abudi', ' evasion'],
#  [' abudi (noun 9/10)', ' pl abudi', ' loophole'],
#  ['abudi (noun 9/10)', ' pl abudi', ' way out'],
#  [' hapana abudi'],
#  [' there is no way out'],
#  [' (< (usually in negative expressions))'],
#  ['abudia (verb applicative)', ' pray for'],
#  [' (< abudu (religious))'],
#  [' abudisha (verb causative)', ' cause to fear'],
#  ['abudisha (verb causative)', ' cause to pray'],
#  [' (< abudu (religious))'],
#  [' abudisha (verb causative)', ' cause to serve'],
#  ['abudisha (verb causative)', ' cause to worship'],
#  [' abudiwa (verb)', ' be worshipped'],
#  [' (< abudu V)'],
#  [' abudu (verb)', ' fear'],
#  [' abudu Mungu'],
#  [' Fear God'],
#  ['abudu (verb)', ' pray'],
#  [' abudu Mungu'],
#  [' Pray to God'],
#  [' (< ibada N)'],
#  [' [Cf'],
#  [' ibada', ' uabudiwaji', ' maabadi', ' maabudu', ' mwabudu]'],
#  ['abudu (verb)', ' serve'],
#  ['  abudu Mungu'],
#  ['  Serve God'],
#  ['abudu (verb)', ' worship'],
#  [' abudu Mungu; walivyoabudu [Masomo 305]'],
#  [' Worship God; the way they worshipped'],
#  [' (< Arabic)'],
#  ['Abunuwasi (noun 1)', ' proper name in tales of Arabic origin'],
#  [' Alisimulia hadithi ya Abunuwasi'],
#  [' S/he told a tale about Abunuwasi'],
#  [' (< (literary))'],
#  [' [Cf'],
#  [' kibanawasi]'],
#  ['Abunuwasi (noun 1)', ' one who tells Abunawasi tales'],
#  ['  (< (literary))'],
#  ['acha (verb)', ' abandon'],
#  [' Waliacha nyumba zao baada ya dharuba'],
#  [' They abandoned their homes after the storm'],
#  ['acha (verb)', ' acquit'],
#  [' acha (verb)', ' allow'],
#  [' acha (verb)', ' cease'],
#  [' acha (verb)', ' desert'],
#  ['acha (verb)', ' discontinue'],
#  ['acha (verb)', ' divorce (someone)'],
#  [' Fulani amemwacha mkewe'],
#  [' X is divorced from his wife'],
#  ['acha (verb)', ' fail to do'],
#  ['acha (verb)', ' leave (behind)'],
#  [' walijiuliza kwa nini hakutaka kumwacha bwana wake [Kez]'],
#  ['acha (verb)', ' neglect'],
#  [' acha (verb)', ' pardon'],
#  [' acha (verb)', ' permit'],
#  ['acha (verb)', ' release'],
#  ['acha (verb)', ' stop'],
#  [' Wameacha kuvuta sigara'],
#  [' They have stopped smoking'],
#  [' achali (noun 9/10)', ' pl achali', ' pickled appetizer'],
#  [' (< ind)'],
#  ['achali (noun 9/10)', ' pl achali', ' chutney'],
#  [' (< ind)'],
#  [' achali (noun 9/10)', ' pl achali', ' relish'],
#  [' (< ind)'],
#  ['achama (verb)', ' gasp'],
#  [' anauweka [mkoba] juu ya meza ukiwa umeachama [Muk]'],
#  ['achama (verb)', ' open mouth wide'],
#  [' achana (verb associative)', ' be different'],
#  ['achana (verb associative)', ' diverge'],
#  [' (< acha V)'],
#  [' achana (verb associative)', ' leave each other'],
#  [' (< acha)'],
#  [' achana (verb associative)', ' separate'],
#  [' (< acha V)'],
#  [' achana (verb associative)', ' be separated'],
#  [' (< acha V)'],
#  ['achana (na) (verb reciprocal)', ' part'],
#  [' hakutaka kuachana na watoto hao [Kez]'],
#  [' (< acha V)'],
#  ['achana na (verb)', ' break up'],
#  [' Maoni yetu ni kwamba mchumba huyu hakufai'],
#  [' Achana naye [Masomo 40]'],
#  [' Our opinion is that fiance is unsuitable for'],
#  ['you'],
#  ['  Break up with hi'],
#  ['m'],
#  [' (< acha V)'],
#  ['achari (noun 9/10)', ' pl achari', ' pickled appetizer'],
#  [' (< ind)'],
#  [' achari (noun 9/10)', ' pl achari', ' chutney'],
#  [' (< ind)'],
#  ['achari (noun 9/10)', ' pl achari', ' relish'],
#  ['  (< ind)'],
#  ['achia (verb applicative)', ' bequeath'],
#  [' achia mtu mali'],
#  [' bequeath property to s'],
#  ['o'],
#  ['achia (verb applicative)', ' leave something to someone'],
#  [' (< acha)'],
#  [' achia (verb applicative)', ' leave for'],
#  [' (< acha V)'],
#  ['achia (verb applicative)', ' let someone have something'],
#  ['achia (verb applicative)', ' let out'],
#  [' "Chloroform"', ' mdomo wa mwanamke unaachia [Muk]'],
#  [' (< acha V)'],
#  ['achia (verb applicative)', ' yield'],
#  [' (< acha V)'],
#  [' achilia (verb applicative)', ' forgive'],
#  ['achilia (verb applicative)', ' pardon'],
#  [' (< acha)'],
#  [' achilia (verb applicative)', ' release'],
#  [' (< acha V)'],
#  ['achilia mbali (verb applicative)', ' abandon'],
#  [' Achilia mbali mambo yako hayo [Chacha', ' Masomo 372]'],
#  [' Forget completely about these issues of yours'],
#  [' (< acha V', ' mbali adv)'],
#  ['achilia mbali (verb applicative)', ' break off'],
#  ['achilia mbali (verb applicative)', ' cease'],
#  [' (< acha)'],
#  [' achilia mbali (verb applicative)', ' leave alone'],
#  [' achilika (verb)', ' be excusable'],
#  [' (< acha)'],
#  [' achilika (verb)', ' be pardonable'],
#  ['achilio (noun 5/6)', ' pl maachilio', ' forgiveness'],
#  [' (< acha V)'],
#  [' achilio (noun 5/6)', ' pl maachilio', ' pardon'],
#  [' (< acha V)'],
#  [' achiliwa (verb)', ' be released'],
#  [' (< acha V)'],
#  ['achisha (verb causative)', ' cause to abandon'],
#  [' achisha (verb causative)', ' cause to divorce'],
#  [' achisha (verb causative)', ' cause to leave'],
#  [' (< acha)'],
#  [' achisha (verb causative)', ' wean (a child)'],
#  ['achwa (verb)', ' be left'],
#  [' (< acha V)'],
#  [' ada (noun 5/6)', ' pl maada', ' contribution'],
#  [' ada (noun 9/10)', ' pl ada', ' custom'],
#  ['ada (noun 9/10)', ' pl ada', ' customary payment'],
#  ['  (< Arabic)'],
#  ['ada (noun 9/10)', ' pl ada', ' fee'],
#  [' ada ya kuingilia'],
#  [' admission fee'],
#  [' (< Arabic)'],
#  ['ada (noun 9/10)', ' pl ada', ' gift (that is expected to be forthcoming)'],
#  [' ada (noun 9/10)', ' pl ada', ' habit'],
#  ['ada (noun 9/10)', ' pl ada', ' manner'],
#  [' ada (noun 5/6)', ' pl maada', ' payment'],
#  ['ada la harusi (noun 5/6)', ' pl maada ya harusi', ' wedding present'],
#  ['ada ya mganga (noun 9/10)', ' pl ada za mganga', " doctor's fee"],
#  [' (< Arabic)'],
#  [' ada ya shule (noun 9/10)', ' pl ada za shule', ' school fee'],
#  [' alikuwa hajatoa'],
#  ['hata chapa kuwalipia watoto ada ya shule [Kez]'],
#  [' (< Arabic)'],
#  [' kiasi cha ada tu (phrase)', ' as is appropriate'],
#  ['kiasi cha ada tu (phrase)', ' as is fitting'],
#  ['adabu (noun 9/10)', ' pl adabu', ' good behavior'],
#  [' adabu (noun 9/10)', ' pl adabu', ' consideration'],
#  [' adabu (noun 9/10)', ' pl adabu', ' courtesy'],
#  ['adabu (noun 9/10)', ' pl adabu', ' manners'],
#  [' Huna adabu'],
#  [' You have no manners'],
#  ['adabu (noun 9/10)', ' pl adabu', ' politeness'],
#  ['Adamu (noun 1)', ' Adam'],
#  [' kutokana na biblia', ' Adamu alikuwa mtu wa kwanza'],
#  [' "according to the Bible', ' Adam was the first person"'],
#  ['adawa (noun 9/10)', ' pl adawa', ' enmity'],
#  [' adawa (noun 9/10)', ' pl adawa', ' hostility'],
#  [' adawa (noun 9/10)', ' pl adawa', ' illwill'],
#  ['Aden (noun)', ' Aden (city)'],
#  [' [also: Edeni] adesi (noun 9/10)', ' pl adesi', ' lentil'],
#  [' [bot]'],
#  ['adha (noun 9/10)', ' pl adha', ' discomfort'],
#  ['  (< Arabic)'],
#  ['adha (noun 9/10)', ' pl adha', ' trouble'],
#  [' leo kuna uzima na afya', ' kesho adha na tafrani [Muk]'],
#  [' (< Arabic)'],
#  ['pa adhabu (verb)', ' chastise'],
#  ['pa adhabu (verb)', ' persecute'],
#  [' pa adhabu (verb)', ' punish'],
#  [' patisha adhabu (verb)', ' chastise'],
#  [' patisha adhabu (verb)', ' persecute'],
#  [' patisha adhabu (verb)', ' punish'],
#  [' tia adhabu (verb)', ' chastise'],
#  ['tia adhabu (verb)', ' persecute'],
#  [' tia adhabu (verb)', ' punish'],
#  ['adhabu (noun 9/10)', ' pl adhabu', ' pain'],
#  [' adhabu (noun 9/10)', ' pl adhabu', ' penalty'],
#  [' adhabu (noun 9/10)', ' pl adhabu', ' persecution'],
#  ['adhabu (noun 9/10)', ' pl adhabu', ' punishment'],
#  [' Adhabu ya uhalifu ilikuwa kutengwa [Masomo 314]'],
#  [' The punishment of the offense was to be isolated'],
#  [' [Cf'],
#  [' adhibu]'],
#  ['adhabu (noun 9/10)', ' pl adhabu', ' pursuit'],
#  ['adhabu (noun 9/10)', ' pl adhabu', ' torment'],
#  [' Ni kosa gani lilotendeka/liloniletea adhabu hii isomalizika? [Alamin Mazrui "Kizuizzini"27]'],
#  [' What mistake was made/that brought me this endless punishment?'],
#  ['adhama (noun 9/10)', ' pl adhama', ' authority'],
#  ['adhama (noun 9/10)', ' pl adhama', ' call to prayer of the muezzin'],
#  [' (< (Islamic))'],
#  ['adhama (noun 9/10)', ' pl adhama', ' dignity'],
#  [' adhama (noun 9/10)', ' pl adhama', ' fame'],
#  ['adhama (noun 9/10)', ' pl adhama', ' glory'],
#  [' Rangi adhama ya Mungu',
#   ' na mwilini si uchafu [Shaaban Robert',
#   ' "Rangi Zetu" 2 ii]'],
#  [' Color is the glory of God', ''],
#  ['and on the body is not unclean'],
#  ['adhama (noun 9/10)', ' pl adhama', ' grandeur'],
#  ['adhama (noun 9/10)', ' pl adhama', ' greatness'],
#  [' [Cf'],
#  [' adhimisho',
#   " 'adhimu",
#   " 'taadhima",
#   " 'taadhimika",
#   ' uadhimishaji / also: adhima]'],
#  ['adhama (noun 9/10)', ' pl adhama', ' honor'],
#  [' adhama (noun 9/10)', ' pl adhama', ' pomp'],
#  [' adhama (noun 9/10)', ' pl adhama', ' power'],
#  [' adhama (noun 9/10)', ' pl adhama', ' splendor'],
#  [' piga adana (verb)', ' call to prayer'],
#  [' (< (Islamic))'],
#  ['adhana (noun 9/10)', ' pl adhana', ' call to prayer of the muezzin'],
#  [' (< (Islamic))'],
#  ['adhibika (verb)', ' be punished'],
#  [' (< adhabu N)'],
#  [' adhibisha (verb)', ' annoy'],
#  ['adhibisha (verb)', ' chastise'],
#  [' adhibisha (verb)', ' harass'],
#  [' adhibisha (verb)', ' pass judgement'],
#  [' adhibisha (verb)', ' molest'],
#  [' adhibisha (verb)', ' cause pain'],
#  ['adhibisha (verb)', ' punish'],
#  [' kumwadhibisha mwanafunzi yeyote [Muk]'],
#  [' (< adhabu N)'],
#  ['adhibisha (verb)', ' sentence'],
#  [' adhibisha (verb)', ' torment'],
#  ['adhibiwa (verb)', ' be punished'],
#  [' Kila mmoja wetu anataka adui huyo aadhibiwe [Nyerere',
#   ' Masomo 274]; Ni haki mtu kuadhibiwa kwa jambo ambalo hakufanya? [Masomo 417]'],
#  [' Every one of us wants this foe to be punished;'],
#  ["Is it just for a person to be punished for something s/he didn't do?"],
#  [' (< adhabu N)'],
#  ['adhibu (verb)', ' annoy'],
#  [' adhibu (verb)', ' chastise'],
#  [' adhibu (verb)', ' harass'],
#  ['adhibu (verb)', ' pass judgement'],
#  [' adhibu (verb)', ' molest'],
#  ['adhibu (verb)', ' cause pain'],
#  ['adhibu (verb)', ' punish'],
#  [' Wakichelewa kurudi kwenye masomo tutawaadhibu [Rech]'],
#  [' If they return late to the lessons we shall punish them [Rech]'],
#  ['(< adhabu N)'],
#  ['adhibu (verb)', ' sentence'],
#  [' adhibu (verb)', ' torment'],
#  ['adhima (noun 9/10)', ' pl adhima', ' authority'],
#  [' adhima (noun 9/10)', ' pl adhima', ' dignity'],
#  [' adhima (noun 9/10)', ' pl adhima', ' fame'],
#  [' adhima (noun 9/10)', ' pl adhima', ' grandeur'],
#  [' adhima (noun 9/10)', ' pl adhima', ' greatness'],
#  [' adhima (noun 9/10)', ' pl adhima', ' pomp'],
#  [' adhima (noun 9/10)', ' pl adhima', ' power'],
#  [' adhima (noun 9/10)', ' pl adhima', ' splendor'],
#  ['adhimia (verb applicative)', ' praise someone'],
#  ['  (< adhimu)'],
#  ['adhimisha (verb causative)', ' celebrate'],
#  [' adhimisha sikukuu'],
#  [' celebrate a holiday'],
#  [' (< adhama N)'],
#  ['adhimisha (verb causative)', ' exalt'],
#  [' (< adhama N)'],
#  [' adhimisha (verb causative)', ' glorify'],
#  [' (< adhama N)'],
#  [' adhimisha (verb causative)', ' honor'],
#  [' (< adhama N)'],
#  [' adhimisha (verb causative)', ' magnify'],
#  [' (< adhimu)'],
#  [' adhimisha (verb causative)', ' praise'],
#  [' (< adhimu)'],
#  ['adhimisho (noun 5/6)', ' pl maadhimisho', ' celebration'],
#  [' adhimisho la misa takatifu'],
#  [' celebration of the mass'],
#  ['adhimisho (noun 5/6)', ' pl maadhimisho', ' ceremony'],
#  [' adhimisho (noun 5/6)', ' pl maadhimisho', ' solemnity'],
#  ['adhimu (verb)', ' celebrate'],
#  [' adhimisha sikukuu'],
#  [' celebrate a holiday'],
#  [' (< adhama N)'],
#  ['adhimu (verb)', ' exalt'],
#  [' (< adhama N)'],
#  [' adhimu (verb)', ' glorify'],
#  [' (< adhama N)'],
#  [' adhimu (verb)', ' honor'],
#  [' (< adhama N)'],
#  [' adhimu (verb)', ' magnify'],
#  [' (< adhama N)'],
#  [' adhimu (verb)', ' praise'],
#  [' (< adhimu)'],
#  ['adhimu (adjective)', ' great'],
#  [' (< adhama N)'],
#  ['  [lit]'],
#  ['adhimu (adjective)', ' important'],
#  [' Kazi yake hii adhimu aifanyayo si rahisi kukadirika [Masomo 395]'],
#  [' It is not easy to measure this significant work of his'],
#  [' (< adhama N)'],
#  [' [lit]'],
#  ['adhimu (adjective)', ' significant'],
#  [' [lit] adhimu (adverb)', ' greatly'],
#  [' [lit] adhimu (adverb)', ' importantly'],
#  [' [lit] adhimu (adverb)', ' significantly'],
#  [' [lit]'],
#  ['adhini (verb)', ' call to prayer (Islam)'],
#  [' Mwadhini anaadhini'],
#  [' The muezzin calls to prayer'],
#  [' (< idhini N)'],
#  [' [Cf'],
#  [' adhana', " mwadhini / also: 'adhana]"],
#  ['adhiri (verb)', ' criticize'],
#  [' adhiri (verb)', ' defame'],
#  [' adhiri (verb)', ' degrade'],
#  ['adhiri (verb)', ' find fault with'],
#  [' Usiniadhiri mbele za watu'],
#  [" Don't criticize me in front of the people"],
#  [" [also: 'aziri]"],
#  ['adhiri (verb)', ' humiliate'],
#  [' adhiri (verb)', ' reprove'],
#  [' adhiri (verb)', ' slander'],
#  ['adhuhuri (noun 9/10)', ' pl adhuhuri', ' midday'],
#  [' wakati wa ~', ' sala ya ~'],
#  [' noontime', ' (Islamic) time of the second prayers'],
#  [' [also: adhuuri]'],
#  ['adhuuri (noun 9/10)', ' pl adhuuri', " noon (between 12 and 2 o'clock)"],
#  [' [also: adhuhuri]'],
#  ['adi (verb)', ' accompany'],
#  [' adi (verb)', ' escort'],
#  ['adi (verb)', ' go part of the way with s'],
#  ['o'],
#  [' (e'],
#  ['g'],
#  ['', ' a guest)'],
#  [' [arch] adia (noun 9/10)', ' pl adia', ' valuable gift'],
#  [' [arch]'],
#  ['adia (noun 9/10)', ' pl adia', ' present'],
#  ['adibisha (verb causative)', ' cause to be brought up'],
#  [' (< adibu)'],
#  [' adibisha (verb causative)', ' cause to be educated'],
#  ['adibisha (verb causative)', ' cause to be taught good manners'],
#  [' adibisha (verb causative)', ' train in good manners'],
#  [' (< adabu N)'],
#  [' adibu (verb)', ' bring up'],
#  [" [also: 'taadabu / Cf"],
#  [' adabu]'],
#  ['adibu (verb)', ' educate'],
#  ['adibu (verb)', ' teach good manners'],
#  [' adibu (adjective)', ' courteous'],
#  ['adibu (adjective)', ' gracious'],
#  [' adibu (adjective)', ' polite'],
#  [' adibu (adjective)', ' wellbred'],
#  ['adibu nafsi yako (phrase)', ' Behave yourself!'],
#  [' adili (verb)', ' conduct oneself well'],
#  ['adili (verb)', ' be impartial'],
#  ['adili (verb)', ' be just'],
#  [' [Cf'],
#  [" 'adilisha", ' uadilifu] adili (verb)', ' be righteous'],
#  ['adili (adjective)', ' correct'],
#  [' adili (adjective)', ' honest'],
#  [' adili (adjective)', ' impartial'],
#  [' adili (adjective)', ' just'],
#  ['adili (adjective)', ' right'],
#  [" [also: 'adilifu] adili (adjective)", ' righteous'],
#  ['adili (adjective)', ' straightforward'],
#  ['adili (noun 5/6)', ' pl maadili', ' honorable conduct'],
#  [' adili (noun 5/6)', ' pl maadili', ' ethics'],
#  ['adili (noun 5/6)', ' pl maadili', ' good conduct'],
#  [' adili (noun 5/6)', ' pl maadili', ' impartiality'],
#  [' adili (noun 5/6)', ' pl maadili', ' justice'],
#  ['adili (noun 5/6)', ' pl maadili', ' morality'],
#  [' adili (noun 5/6)', ' pl maadili', ' morals'],
#  [' adilifu (adjective)', ' correct'],
#  ['adilifu (adjective)', ' honest'],
#  [' adilifu (adjective)', ' impartial'],
#  [' adilifu (adjective)', ' just'],
#  ['adilifu (adjective)', ' right'],
#  [" [also: 'adili] adilifu (adjective)", ' righteous'],
#  ['adilifu (adjective)', ' straightforward'],
#  [' adilisha (verb)', ' cause to be moral'],
#  [' adilisha (verb)', ' teach morality'],
#  ['adilisha (verb)', ' cause to be righteous'],
#  [' (< adili)'],
#  [' adilisha (verb)', ' teach good conduct'],
#  ['adilisha (verb)', ' teach right conduct'],
#  [' (< adili N)'],
#  [' adimika (verb)', ' be obtainable'],
#  ['adimika (verb)', ' be rare'],
#  [' [Cf'],
#  [" 'adimu / also: hadimika] adimika (verb)", ' be scarce'],
#  [' (< adimu adv)'],
#  ['adimu (adjective)', ' deficient'],
#  [' [Cf'],
#  [" 'adimika] adimu (adjective)", ' faulty'],
#  ['adimu (adjective)', ' inadequate'],
#  ['adimu (adjective)', ' insufficient'],
#  ['  [Cf'],
#  [" 'adimika]"],
#  ['adimu (adjective)', ' rare'],
#  [' mwanamke anaweza kuwa kama kitu adimu sana [Kez]'],
#  [' (< Arabic)'],
#  ['adimu (adjective)', ' scarce'],
#  [' (< Arabic)'],
#  [' adimu (adjective)', ' unobtainable'],
#  [' adimu (adjective)', ' unsatisfactory'],
#  ['adinasi (noun 9/10an)', ' pl adinasi', ' free man'],
#  [' [arch] adinasi (noun 9/10an)', ' pl adinasi', ' man of good birth'],
#  [' admeli (noun 9/10an)', ' pl admeli', ' admiral'],
#  [' [also: admirali] admirali (noun 9/10an)', ' pl admirali', ' admiral'],
#  [' [also: admeli]'],
#  ['adua (verb)', ' prepare magical charms (against the evil eye)'],
#  [' [arch] adua (verb)', ' make offerings'],
#  [' [arch]'],
#  ['adua (verb)', ' make sacrifices'],
#  [' [arch]'],
#  ['adui (noun 5/6an)', ' pl maadui', ' enemy'],
#  [' mfano wa maadui', ' hakuna aliyemwambia mwenzake "kwi" [Sul]'],
#  [' (< Arabic)'],
#  ['adui (noun 5/6an)', ' pl maadui', ' foe'],
#  [' Kila mmoja wetu anataka adui huyo afukuzwe nje ya mipaka yetu [Nyerere',
#   ' Masomo 274]'],
#  [' Every one of us wants this foe to be driven outside of our borders'],
#  ['adui (noun 5/6an)', ' pl maadui', ' opponent'],
#  [' aenzi (verb)', ' exalt'],
#  ['aenzi (verb)', ' glorify'],
#  ['aenzi (verb)', ' inaugurate (as a ruler)'],
#  [' aenzi (verb)', ' install'],
#  ['aenzi (verb)', ' invest with power'],
#  [' aenzi (noun 9/10)', ' pl aenzi', ' dominion'],
#  ['aenzi (noun 9/10)', ' pl aenzi', ' power'],
#  [' kiti cha ~', ' katika ~ ya'],
#  [' throne', ' during the reign of'],
#  [' [also: enzi', ' ezi]'],
#  ['aenzi (noun 9/10)', ' pl aenzi', ' rule'],
#  ['  [also: enzi', ' ezi]'],
#  ['aenzi (noun 9/10)', ' pl aenzi', ' sovereignty'],
#  ['  [also: enzi', ' ezi]'],
#  ['afa (noun 5/6)', ' pl maafa', ' accident'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' bad luck'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' calamity'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' catastrophe'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' damage'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' danger'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' disaster'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' horror'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' injury'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' injustice'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' menace'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' misfortune'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' mishap'],
#  [' [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' peril'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' terror'],
#  ['  [more commonly pl'],
#  [': maafa]'],
#  ['afa (noun 5/6)', ' pl maafa', ' threat'],
#  [' [more commonly pl'],
#  [': maafa] afadhali (adverb)', ' better'],
#  [' ni afadhali kusafiri kuliko kukaa'],
#  [' It is'],
#  ['better to travel than to stay'],
#  [' [Cf'],
#  [' fadhili / also: afdhali', ' afudhali] afadhali (adverb)', ' particularly'],
#  ['afadhali (adverb)', ' preferable'],
#  [' afadhali (adverb)', ' preferably'],
#  [' afadhali (adverb)', ' rather'],
#  ['afande (noun 9/10)', ' pl afande', ' title used by soldiers and police'],
#  [' vocat'],
#  [' yes', ' sir! "Askari!" Yohana aliita'],
#  [' "Afande!" [Ng]'],
#  [' (< Turkish)'],
#  ['afdhali (adverb)', ' better'],
#  [' ni ~ kusafiri kuliko kukaa'],
#  [' It is better to travel than to stay'],
#  [' [Cf'],
#  [' fadhili / also: afadhali', ' afudhali]'],
#  ['afdhali (adverb)', ' particularly'],
#  [' afdhali (adverb)', ' preferable'],
#  [' afdhali (adverb)', ' preferably'],
#  [' afdhali (adverb)', ' rather'],
#  ['afendi (noun 9/10)', ' pl afendi', ' effendi (Turkish title of rank)'],
#  [' [mil] afia (noun 9/10)', ' pl afia', ' health'],
#  [' bora ~; hana ~ nzuri', ' ~ yake si'],
#  ['nzuri'],
#  [' The main thing is health; He is not in good health'],
#  [' [also: afya] afia (noun 9/10)', ' pl afia', ' strength'],
#  ['afia (noun 9/10)', ' pl afia', ' vigor'],
#  ['afikana (verb associative)', ' agree together'],
#  ['afikana (verb associative)', ' come to an agreement'],
#  [' (< afiki)'],
#  [' afikana (verb associative)', ' compromise'],
#  [' (< afiki)'],
#  ['afikana (verb associative)', ' make a contract'],
#  [' (< afiki)'],
#  [' afikana (verb associative)', ' be reconciled'],
#  ['afikana (verb associative)', ' make a settlement'],
#  [' afikana (verb associative)', ' come to an understanding'],
#  [' afikanisha (verb causative)', ' appease'],
#  ['afikanisha (verb causative)', ' conciliate'],
#  [' afikanisha (verb causative)', ' reconcile'],
#  ['afikanisha (verb causative)', ' satisfy'],
#  [' (< afika)'],
#  [' [Cf'],
#  [' maafikiano', ' mwafaka]'],
#  ['afiki (verb)', ' agree'],
#  ['  [usually ass'],
#  [": 'afikana]"],
#  ['afiki (verb)', ' agree (with)'],
#  [' wanatikisa vichwa vyao katika kuafiki [Muk]'],
#  [' They are shaking their heads in agreement'],
#  [' (< Arabic)'],
#  ['afiki (verb)', ' appease'],
#  [' afiki (verb)', ' assent'],
#  [' afiki (verb)', ' correspond'],
#  ['afiki (verb)', ' fit'],
#  ['afiki (verb)', ' be fitting'],
#  ['afiki (verb)', ' be the same as'],
#  [' afiki (verb)', ' satisfy'],
#  ['afikiana (verb associative)', ' agree together'],
#  [' akimtazama msichana huyo ambaye alikuwa akiafikiana naye katika kioo [Mt]'],
#  [' (< Arabic)'],
#  ['afikiana (verb associative)', ' come to an agreement'],
#  [' (< afiki v)'],
#  [' afikiana (verb associative)', ' compromise'],
#  [' (< afiki v)'],
#  ['afikiana (verb associative)', ' make a contract'],
#  [' (< afiki v)'],
#  [' afikiana (verb associative)', ' be reconciled'],
#  [' (< afiki v)'],
#  [' afikiana (verb associative)', ' make a settlement'],
#  [' (< Arabic)'],
#  ['afikiana (verb associative)', ' come to an understanding'],
#  [' Kama hutaki kuafikiana nami nitatumia madaraka yangu [Chacha',
#   ' Masomo 383]'],
#  [" If you don't want to come to an understanding with me I will use my authority "],
#  [' (< afiki v)'],
#  ['afikiano (noun 5/6)', ' pl maafikiano', ' agreement'],
#  [' (< afiki v)'],
#  [' afikiano (noun 5/6)', ' pl maafikiano', ' compromise'],
#  [' (< afiki v)'],
#  [' afikiano (noun 5/6)', ' pl maafikiano', ' pact'],
#  [' (< afiki v)'],
#  [' afikiano (noun 5/6)', ' pl maafikiano', ' settlement'],
#  [' (< afiki v)'],
#  ['afiriti (noun 9/10an)', ' pl afiriti', ' evil genius'],
#  [' basi tokeni wewe na huyo afiriti mwenzako [Moh]'],
#  [' (< Arabic)'],
#  ['afiriti (noun 9/10an)', ' pl afiriti', ' wicked person'],
#  [' basi tokeni wewe na huyo afiriti mwenzako [Moh]'],
#  [' (< Arabic)'],
#  ['afisa (noun 5/6an)', ' pl maafisa', ' military officer'],
#  ['afisa (noun 5/6an)', ' pl maafisa', ' officer'],
#  [' siku hiyo hiyo alikuja afisa'],
#  ['mmoja Mzungu [Ng]; Maafisa ya kilimo [Masomo 154]'],
#  [' On that very day a European officer came; agricultural officers'],
#  [' (< Eng'],
#  [')'],
#  ['afisa (noun 5/6an)', ' pl maafisa', ' official'],
#  [' [Cf'],
#  [' uafisa / also: ofisa] afisi (noun 9/10)', ' pl afisi', ' bureau'],
#  ['afisi (noun 9/10)', ' pl afisi', ' department'],
#  ['afisi (noun 9/10)', ' pl afisi', ' office'],
#  [' (< also: ofisi)'],
#  ['afiuni (noun 9/10)', ' pl afiuni', ' opium'],
#  [' [also: afyuni / syn'],
#  [': kasumba] Afrika (noun 9)', ' Africa'],
#  [' [Cf'],
#  [' kiafrika', ' Mwafrika]'],
#  ['Afrika ya Kati (noun 9)', ' Central Africa'],
#  [' afrikanaizesheni (noun 9)', ' Africanization'],
#  [' afriti (noun 9/10an)', ' pl afriti', ' devil'],
#  ['afriti (noun 5/6an)', ' pl afriti', ' evil genius'],
#  [' (< Arabic)'],
#  [' afriti (noun 9/10an)', ' pl afriti', ' malicious person'],
#  [' afriti (noun 9/10an)', ' pl afriti', ' evil spirit'],
#  ['afriti (noun 9/10an)', ' pl afriti', ' wicked person'],
#  [' afu (verb)', ' cure'],
#  ['afu (verb)', ' defend'],
#  ['afu (verb)', ' deliver from calamity'],
#  [' afu (verb)', ' forgive'],
#  [" [also: 'afua] afu (verb)", ' free'],
#  ['afu (verb)', ' guard'],
#  [' afu (verb)', ' heal'],
#  [' afu (verb)', ' help'],
#  [' afu (verb)', ' liberate'],
#  [' afu (verb)', ' pardon'],
#  [' afu (verb)', ' protect'],
#  [' afu (verb)', ' release'],
#  [' afu (verb)', ' save'],
#  ['afu (noun 9/10)', ' pl afu', ' defense'],
#  ['afu (noun 9/10)', ' pl afu', ' deliverance from calamity'],
#  ['afu (noun 9/10)', ' pl afu', ' flower of the wild jasmine'],
#  ['  [Cf'],
#  [' mwafu]'],
#  ['afu (noun 9/10)', ' pl afu', ' jasmine blossoms (wild)'],
#  [' Hupamba nyota na mbingu',
#   ' na mawaridi na afu [Shaaban Robert',
#   ' "Rangi Zetu" 2 i]'],
#  [' He ornaments the stars and the heavens', ' roses and jasmine'],
#  ['afu (noun 9/10)', ' pl afu', ' liberation'],
#  [' afu (noun 9/10)', ' pl afu', ' protection'],
#  [' afu (noun 9/10)', ' pl afu', ' redemption'],
#  ['afu (noun 9/10)', ' pl afu', ' salvation'],
#  [' afua (verb)', ' cure'],
#  [' (< afu V)'],
#  [' afua (verb)', ' defend'],
#  ['afua (verb)', ' deliver from calamity'],
#  [' (< afu V)'],
#  [' afua (verb)', ' forgive'],
#  [" [also: 'afu]"],
#  ['afua (verb)', ' free'],
#  [' afua (verb)', ' guard'],
#  [' afua (verb)', ' heal'],
#  [' afua (verb)', ' liberate'],
#  ['afua (verb)', ' pardon'],
#  [' (< afu V)'],
#  [' afua (verb)', ' protect'],
#  ['afua (verb)', ' release'],
#  ['afua (verb)', ' save'],
#  [' (< afu V)'],
#  ['afua (noun 9/10)', ' pl afua', ' defense'],
#  [' afua (noun 9/10)', ' pl afua', ' liberation'],
#  [' afua (noun 9/10)', ' pl afua', ' protection'],
#  [' afua (noun 9/10)', ' pl afua', ' redemption'],
#  [' afua (noun 9/10)', ' pl afua', ' salvation'],
#  ['afudhali (adverb)', ' better'],
#  [' ni ~ kusafiri kuliko kukaa'],
#  [' It is better to travel than to stay'],
#  [' [Cf'],
#  [' fadhili / also: afadhali', ' afdhali]'],
#  ['afudhali (adverb)', ' particularly'],
#  [' afudhali (adverb)', ' preferably'],
#  [' afudhali (adverb)', ' rather'],
#  ['likizo ya afueni (noun)', ' convalescent leave'],
#  [' afya (verb)', ' put on oath'],
#  [' (< apa)'],
#  ['afya (verb)', ' sneeze'],
#  ['afya (noun 9/10)', ' pl afya', ' health'],
#  [' bora ~', ' hana ~ nzuri or ~ yake si nzuri'],
#  [' The main thing is health', ' He is not in good health'],
#  [' (< also: afia)'],
#  ['afya (noun 9/10)', ' pl afya', ' strength'],
#  [' afya (noun 9/10)', ' pl afya', ' vigor'],
#  [' Afya (phrase)', ' good health'],
#  ['afya (phrase)', ' response to a sneeze'],
#  ['afyuni (noun 9/10)', ' pl afyuni', ' opium'],
#  ['  [also: afiuni / syn: kasumba]'],
#  ['aga (verb)', ' agree'],
#  [' (< (usu'],
#  [' ass'],
#  ['))'],
#  [' [usu'],
#  [' ass'],
#  [": 'agana / Cf"],
#  [' agano', ' agizo', ' kiaga', ' mwago', ' uagizaji]'],
#  ['aga (verb)', ' agree with'],
#  ['aga (verb)', ' come to an agreement'],
#  [' aga (verb)', ' make a contract'],
#  ['aga (verb)', ' destroy'],
#  ['aga (verb)', ' say goodbye'],
#  [' Alikuwa amekuja kumuaga babuye [Balisidya', ' Masomo 352]'],
#  [' She had come to say goodbye to her grandfather'],
#  ['aga (verb)', ' leave'],
#  ['aga (verb)', " take one's leave"],
#  [' aga dunia'],
#  [' to die (euphemism)'],
#  [' [Cf'],
#  [' agano', ' kiago', ' mwango]'],
#  ['aga (verb)', ' take leave of'],
#  [' kukitazama chumba chake kama mtu anayekiaga [Muk]'],
#  ['Agami (noun)', ' pl (sing'],
#  [')', ' Iran'],
#  ['Agami (noun)', ' pl (sing'],
#  [')', ' Persia'],
#  [' [also: Uajemi', ' Ajemi / Cf'],
#  [' Kiajemi', ' Mwajemi]'],
#  ['Agami (noun)', ' Iran'],
#  [' agana (verb)', ' agree'],
#  ['agana (verb)', ' make an agreement'],
#  [' (< aga V)'],
#  [' agana (verb)', ' make a contract'],
#  ['agana (verb)', ' say goodbye (to each other)'],
#  [' (< aga V)'],
#  ['agana (verb)', ' take leave of each other (for a long period)'],
#  [' (< aga)'],
#  [' agana (verb reciprocal)', ' make a pact'],
#  [' pale waaganapo kukutana kiwanja'],
#  ['cha hoki [Sul]'],
#  [' (< aga V)'],
#  ['agana (verb reciprocal)', ' take leave of each other'],
#  [' karibu ya kuagana', ' Subira hakujizuia tena [Sul]'],
#  [' (< aga V)'],
#  ['agana buriani (verb)', ' bid each other a final farewell'],
#  [' (< aga)'],
#  [' agano (noun 5/6)', ' pl maagano', ' agreement'],
#  [' ~ Jipya', ' ~ la Kale'],
#  [' New'],
#  ['Testament', ' Old Testament'],
#  [' (< (usually plural))'],
#  [' agano (noun 5/6)', ' pl maagano', ' arrangement'],
#  [' agano (noun 5/6)', ' pl maagano', ' contract'],
#  [' (< aga V)'],
#  [' agano (noun 5/6)', ' pl maagano', ' covenant'],
#  ['agano (noun 5/6)', ' pl maagano', ' departure'],
#  [' [rare] agano (noun 5/6)', ' pl maagano', ' farewell'],
#  ['agano (noun 5/6)', ' pl maagano', ' pact'],
#  [' (< aga V)'],
#  [' agano (noun 5/6)', ' pl maagano', ' parting'],
#  [' (< aga V)'],
#  ['agano (noun 5/6)', ' pl maagano', ' promise'],
#  [' (< aga V)'],
#  [' [Cf'],
#  [" 'aga] agano (noun 5/6)", ' pl maagano', ' settlement'],
#  ['agano (noun 5/6)', ' pl maagano', ' testament'],
#  [' (< aga V)'],
#  [' agano (noun 5/6)', ' pl maagano', ' treaty'],
#  ['agano (noun 5/6)', ' pl maagano', ' understanding'],
#  [' agano (noun 5/6)', ' pl maagano', ' vow'],
#  ['Agano la Kale (phrase)', ' Old Testament'],
#  [' masimulizi yake',
#   ' hususan ya Agano la Kale',
#   ' humvutia na kumsisimua sana [Muk]'],
#  [' (< agana V', ' kale adv)'],
#  ['aghalabu (adverb)', ' chiefly'],
#  [' (< Arabic)'],
#  [' aghalabu (adverb)', ' mainly'],
#  [' (< Arabic)'],
#  ['aghalabu (adverb)', ' more often'],
#  [' aghalabu siku za wikendi msichana huyu hutoka [Muk]'],
#  [' more often on the weekend this girl went out'],
#  [' (< Arabic)'],
#  ['aghalabu (adverb)', ' mostly'],
#  [' aghalabu (adverb)', ' ordinarily'],
#  [' aghalabu (adverb)', ' as a rule'],
#  ['aghalabu (adverb)', ' usually'],
#  [' Mshairi aghalabu huzaliwa na kipawa maalum cha ushairi [Masomo 395]; maji huchotwa kwa ndoo',
#   " ~ na ng'ombe"],
#  [' A poet is usually born with a special poetic ability; water is drawn with buckets',
#   ''],
#  ['but the work is usually done by oxen'],
#  [' (< Arabic)'],
#  [' [also: aghlabu] aghlabu (adverb)', ' chiefly'],
#  ['aghlabu (adverb)', ' mainly'],
#  [' aghlabu (adverb)', ' more often'],
#  [' aghlabu (adverb)', ' mostly'],
#  [' aghlabu (adverb)', ' ordinarily'],
#  [' aghlabu (adverb)', ' as a rule'],
#  ['aghlabu (adverb)', ' usually'],
#  [' maji huchotwa kwa ndoo', " ~ na ng'ombe"],
#  [' "Water is drawn with buckets', ' but the work is usually done by oxen"'],
#  [' [also: aghalabu]'],
#  ['agia (verb applicative)', ' befit'],
#  [' (< aga V)'],
#  [' agia (verb applicative)', ' suit'],
#  [' (< aga V)'],
#  ['agiza (verb causative)', ' charge'],
#  [' fanya kama nilivyokuagiza'],
#  [' Do as I have instructed you'],
#  [' (< aga)'],
#  ['agiza (verb causative)', ' commission'],
#  [' akafika kuagiza wenzake wamsaidie kutafuta kazi pahala pengine [Sul]'],
#  [' and he arrive and commissioned his friends to help him look for work in another place'],
#  [' (< aga V)'],
#  ['agiza (verb causative)', ' direct'],
#  [' agiza (verb causative)', ' instruct'],
#  ['agiza (verb causative)', ' give instructions'],
#  [' agiza (verb causative)', ' order'],
#  [' (< aga V)'],
#  ['agizia (verb applicative)', ' order for'],
#  [' barua za kuagizia [Masomo', ' 75]'],
#  [' letters to order things'],
#  [' (< aga)'],
#  ['agizo (noun 5/6)', ' pl maagizo', ' commission'],
#  ['agizo (noun 5/6)', ' pl maagizo', ' direction'],
#  [' (< aga V)'],
#  [' agizo (noun 5/6)', ' pl maagizo', ' directive'],
#  [' (< aga V)'],
#  [' agizo (noun 5/6)', ' pl maagizo', ' instruction'],
#  [' (< agiza V)'],
#  ['agizo (noun 5/6)', ' pl maagizo', ' order'],
#  [' watu wanaodharau maagizo ya Chama [Mun]'],
#  [' [usually pl'],
#  [' maaguzi / Cf'],
#  [" 'aga]"],
#  ['agizo (noun 5/6)', ' pl maagizo', ' regulation'],
#  [' agizwa (verb)', ' be ordered'],
#  [' (< aga V)'],
#  [' Agosti (noun 9)', ' August'],
#  ['agua (verb)', ' divine'],
#  ['agua (verb)', ' foretell'],
#  [' [Cf'],
#  [' aguzi',
#   ' mwaguzi',
#   ' uaguzi] agua (verb)',
#   ' interpret (a dream or omen)'],
#  ['agua (verb)', ' predict'],
#  ['agua (verb)', ' prophesy'],
#  ['agua (verb)', ' treat (usu'],
#  [' with charms or potions)'],
#  [' [med] agulia (verb applicative)', ' predict'],
#  [' mmoja alimwagulia: "mpaka'],
#  ['ataporambishwa asali" [Sul]'],
#  ['  (< agua V)'],
#  ['agulia (verb applicative)', ' prophesy'],
#  [' (< agua V)'],
#  [' aguliwa (verb)', ' be predicted'],
#  [' (< agua V)'],
#  ['aguzi (noun 5/6)', ' pl maaguzi', ' apparatus for removing a spell'],
#  [' (< agua V)'],
#  ['aguzi (noun 5/6)', ' pl maaguzi', ' interpretation (of a dream or omen)'],
#  [' aguzi (noun 5/6)', ' pl maaguzi', ' medicine'],
#  [' (< (usu'],
#  [' pl'],
#  ['))'],
#  [' [usually pl'],
#  ['maaguzi; Cf'],
#  [" 'agua]"],
#  ['aguzi (noun 5/6)', ' pl maaguzi', ' prediction'],
#  [' (< agua V)'],
#  [' aguzi (noun 5/6)', ' pl maaguzi', ' prophesy'],
#  ['aguzi (noun 5/6)', ' pl maaguzi', ' remedy'],
#  [' ah (interjection)', ' expresses joy'],
#  ['ah (interjection)', ' expresses pain'],
#  ['ah (interjection)', ' expresses surprise'],
#  [' [also: a', ' aa] fikisha ahadi (verb)', ' keep a promise'],
#  ['fikisha ahadi (verb)', ' keep a vow'],
#  [' funga ahadi (verb)', ' make a promise'],
#  [' pa ahadi (verb)', ' make a promise'],
#  ['shika ahadi (verb)', ' keep a promise'],
#  [' [Cf'],
#  [" 'ahidi", ' miadi / also: wahadi]'],
#  ['shika ahadi (verb)', ' keep a vow'],
#  [' [Cf'],
#  [" 'ahidi", ' miadi / also: wahadi] timiza ahadi (verb)', ' keep a promise'],
#  [' [Cf'],
#  [" 'ahidi", ' miadi / also:'],
#  ['wahadi]'],
#  ['timiza ahadi (verb)', ' keep a vow'],
#  [' [Cf'],
#  [" 'ahidi", ' miadi / also: wahadi] toa ahadi (verb)', ' make a promise'],
#  ['vunja ahadi (verb)', ' break a promise'],
#  [' [Cf'],
#  [" 'ahidi", ' miadi / also: wahadi]'],
#  ['vunja ahadi (verb)', ' break a vow'],
#  ['ahadi (noun 9/10)', ' pl ahadi', ' agreement'],
#  [' ahadi (noun 9/10)', ' pl ahadi', ' covenant'],
#  [' ahadi (noun 9/10)', ' pl ahadi', ' obligation'],
#  ['ahadi (noun 9/10)', ' pl ahadi', ' promise'],
#  [" toa ('funga", " 'pa) ~", " 'vunja ~", " 'tizima ('fikisha", " 'shika) ~"],
#  [' make a promise', ' break a promise/vow', ' keep a promise/vow'],
#  [' [Cf'],
#  [" 'ahidi", ' miadi / also: wahadi]'],
#  ['ahadi (noun 9/10)', ' pl ahadi', ' vow'],
#  [' ahali (noun 9/10an)', ' pl ahali', ' family'],
#  ['ahali (noun 9/10an)', ' pl ahali', ' relations'],
#  [' (< also: ahli)'],
#  ['ahali (noun 9/10an)', ' pl ahali', ' relative (distant)'],
#  [' ndugu na ahali'],
#  [' brothers and (other) relatives'],
#  ['ahali (noun 9/10an)', ' pl ahali', ' wife'],
#  ['  [rare]'],
#  ['ahera (noun 9/10)', ' pl ahera', ' afterlife'],
#  [' adhabu inayowangoja kesho ahera [Masomo 391]'],
#  ['ahera (noun 9/10)', ' pl ahera', ' hereafter'],
#  [' enda ahera'],
#  [' to die (figurative)'],
#  [' (< also: akhera)'],
#  [' [Cf'],
#  [' aheri]'],
#  ['ahera (noun 9/10)', ' pl ahera', ' life to come'],
#  [' ahera (noun 9/10)', ' pl ahera', ' next world'],
#  [' aheri (noun 9/10)', ' pl aheri', ' border'],
#  ['aheri (noun 9/10)', ' pl aheri', ' end'],
#  ...]

# %%
neno_word_trans_dictionary = []
for i in neno_lines:
    for l in i:
        swahili_word_regex = re.search(r"(\w+) (\(.*\))", l.strip())
        if swahili_word_regex != None and i.index(l) == 0:
            uwingi:str=""
            word:str=""
            if len(i) == 2:
                word = i[1].strip()
            elif len(i) == 3:
                if re.search(r"pl (\w+)", i[1].strip()) != None:
                    uwingi = re.search("pl (\w+)", i[1]).group(1)
                    
                word = re.sub(r"(\w+) [\(\w+\)]", "\1", i[2].strip())
            
            neno_word_trans_dictionary.append({"neno": swahili_word_regex.group(1),
                                               "tag": re.sub("[()]", "", swahili_word_regex.group(2)),
                                              "word": word,
                                              "uwingi": uwingi})
            continue
neno_word_trans_dictionary
# Out:
# [{'neno': 'a',
#   'tag': 'preposition',
#   'word': 'of (a + noun used to form possessives)',
#   'uwingi': ''},
#  {'neno': 'a',
#   'tag': 'preposition',
#   'word': 'of (a + noun used to form adjectives)',
#   'uwingi': ''},
#  {'neno': 'a', 'tag': 'interjection', 'word': 'expresses joy', 'uwingi': ''},
#  {'neno': 'a', 'tag': 'interjection', 'word': 'expresses pain', 'uwingi': ''},
#  {'neno': 'a',
#   'tag': 'interjection',
#   'word': 'expresses surprise',
#   'uwingi': ''},
#  {'neno': 'aa', 'tag': 'interjection', 'word': 'expresses joy', 'uwingi': ''},
#  {'neno': 'aa', 'tag': 'interjection', 'word': 'expresses pain', 'uwingi': ''},
#  {'neno': 'aa',
#   'tag': 'interjection',
#   'word': 'expresses surprise',
#   'uwingi': ''},
#  {'neno': 'aali', 'tag': 'adjective', 'word': 'excellent', 'uwingi': ''},
#  {'neno': 'aali', 'tag': 'adjective', 'word': 'firstclass', 'uwingi': ''},
#  {'neno': 'aali', 'tag': 'adjective', 'word': 'good', 'uwingi': ''},
#  {'neno': 'aasi', 'tag': 'verb', 'word': 'be disobedient', 'uwingi': ''},
#  {'neno': 'aasi',
#   'tag': 'verb',
#   'word': 'not meet an obligation',
#   'uwingi': ''},
#  {'neno': 'aasi', 'tag': 'verb', 'word': 'rebel', 'uwingi': ''},
#  {'neno': 'aasi', 'tag': 'verb', 'word': 'revolt', 'uwingi': ''},
#  {'neno': 'aasi', 'tag': 'noun 5/6', 'word': 'rebellion', 'uwingi': 'maasi'},
#  {'neno': 'aasi', 'tag': 'noun 5/6', 'word': 'revolt', 'uwingi': 'maasi'},
#  {'neno': 'abadan', 'tag': 'adverb', 'word': 'never', 'uwingi': ''},
#  {'neno': 'abadan', 'tag': 'interjection', 'word': 'Make way!', 'uwingi': ''},
#  {'neno': 'abadi', 'tag': 'adverb', 'word': 'always', 'uwingi': ''},
#  {'neno': 'abadi', 'tag': 'adverb', 'word': 'constantly', 'uwingi': ''},
#  {'neno': 'abd', 'tag': 'noun 9/10an', 'word': 'servant', 'uwingi': 'abd'},
#  {'neno': 'abd', 'tag': 'noun 9/10an', 'word': 'slave', 'uwingi': 'abd'},
#  {'neno': 'Abdallah', 'tag': 'noun', 'word': 'Abdullah', 'uwingi': ''},
#  {'neno': 'abe',
#   'tag': 'interjection',
#   'word': 'At your service!',
#   'uwingi': ''},
#  {'neno': 'abe', 'tag': 'interjection', 'word': "Yes ma'am!", 'uwingi': ''},
#  {'neno': 'abe', 'tag': 'interjection', 'word': 'Yes sir!', 'uwingi': ''},
#  {'neno': 'abedari', 'tag': 'interjection', 'word': 'Look out!', 'uwingi': ''},
#  {'neno': 'abedari',
#   'tag': 'interjection',
#   'word': 'Take care!',
#   'uwingi': ''},
#  {'neno': 'abedari',
#   'tag': 'interjection',
#   'word': 'Watch out!',
#   'uwingi': ''},
#  {'neno': 'abedari',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01hows)',
#   'uwingi': 'abedari'},
#  {'neno': 'abee',
#   'tag': 'interjection',
#   'word': 'at your service',
#   'uwingi': ''},
#  {'neno': 'abee', 'tag': 'interjection', 'word': 'I am coming', 'uwingi': ''},
#  {'neno': 'abee', 'tag': 'interjection', 'word': 'Yes sir!', 'uwingi': ''},
#  {'neno': 'abee', 'tag': 'interjection', 'word': "Yes ma'am!", 'uwingi': ''},
#  {'neno': 'abidi', 'tag': 'adverb', 'word': 'always', 'uwingi': ''},
#  {'neno': 'abidi', 'tag': 'adverb', 'word': 'constantly', 'uwingi': ''},
#  {'neno': 'abidi', 'tag': 'adverb', 'word': 'rare', 'uwingi': ''},
#  {'neno': 'abiri',
#   'tag': 'verb',
#   'word': 'cross (river or lake or sea)',
#   'uwingi': ''},
#  {'neno': 'abiri', 'tag': 'verb', 'word': 'go (i', 'uwingi': ''},
#  {'neno': 'abiri', 'tag': 'verb', 'word': 'pass over', 'uwingi': ''},
#  {'neno': 'abiri',
#   'tag': 'verb',
#   'word': 'travel (as passenger)',
#   'uwingi': ''},
#  {'neno': 'abiri', 'tag': 'verb', 'word': 'travel (by sea)', 'uwingi': ''},
#  {'neno': 'abiria', 'tag': 'verb', 'word': 'travel to', 'uwingi': ''},
#  {'neno': 'abiria',
#   'tag': 'noun 9/10an',
#   'word': 'passenger',
#   'uwingi': 'maabiria'},
#  {'neno': 'abirika', 'tag': 'verb', 'word': 'travel', 'uwingi': ''},
#  {'neno': 'abirisha',
#   'tag': 'verb',
#   'word': 'convey (as passenger)',
#   'uwingi': ''},
#  {'neno': 'abirisha', 'tag': 'verb', 'word': 'cause to travel', 'uwingi': ''},
#  {'neno': 'abiriwa', 'tag': 'verb', 'word': 'be crossed (i', 'uwingi': ''},
#  {'neno': 'abiriwa', 'tag': 'verb', 'word': 'be passed over (i', 'uwingi': ''},
#  {'neno': 'abiriwa', 'tag': 'verb', 'word': 'be travelled (i', 'uwingi': ''},
#  {'neno': 'abos',
#   'tag': 'interjection',
#   'word': 'exclamation of admiration',
#   'uwingi': ''},
#  {'neno': 'abu', 'tag': 'noun 9/10an', 'word': 'father', 'uwingi': 'abu'},
#  {'neno': 'abudi',
#   'tag': 'noun 9/10',
#   'word': 'alternative',
#   'uwingi': 'abudi'},
#  {'neno': 'abudi', 'tag': 'noun 9/10', 'word': 'evasion', 'uwingi': 'abudi'},
#  {'neno': 'abudi', 'tag': 'noun 9/10', 'word': 'loophole', 'uwingi': 'abudi'},
#  {'neno': 'abudi', 'tag': 'noun 9/10', 'word': '\x01ut', 'uwingi': 'abudi'},
#  {'neno': 'abudia',
#   'tag': 'verb applicative',
#   'word': 'pray for',
#   'uwingi': ''},
#  {'neno': 'abudu', 'tag': 'religious', 'word': '', 'uwingi': ''},
#  {'neno': 'abudisha',
#   'tag': 'verb causative',
#   'word': 'cause to fear',
#   'uwingi': ''},
#  {'neno': 'abudisha',
#   'tag': 'verb causative',
#   'word': 'cause to pray',
#   'uwingi': ''},
#  {'neno': 'abudu', 'tag': 'religious', 'word': '', 'uwingi': ''},
#  {'neno': 'abudisha',
#   'tag': 'verb causative',
#   'word': 'cause to serve',
#   'uwingi': ''},
#  {'neno': 'abudisha',
#   'tag': 'verb causative',
#   'word': 'cause to worship',
#   'uwingi': ''},
#  {'neno': 'abudiwa', 'tag': 'verb', 'word': 'be worshipped', 'uwingi': ''},
#  {'neno': 'abudu', 'tag': 'verb', 'word': 'fear', 'uwingi': ''},
#  {'neno': 'abudu', 'tag': 'verb', 'word': 'pray', 'uwingi': ''},
#  {'neno': 'abudu', 'tag': 'verb', 'word': 'serve', 'uwingi': ''},
#  {'neno': 'abudu', 'tag': 'verb', 'word': 'worship', 'uwingi': ''},
#  {'neno': 'Abunuwasi',
#   'tag': 'noun 1',
#   'word': 'proper name in tales of Arabic origin',
#   'uwingi': ''},
#  {'neno': 'Abunuwasi',
#   'tag': 'noun 1',
#   'word': 'one who tells Abunawasi tales',
#   'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'abandon', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'acquit', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'allow', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'cease', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'desert', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'discontinue', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'divorce (someone)', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'fail to do', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'leave (behind)', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'neglect', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'pardon', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'permit', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'release', 'uwingi': ''},
#  {'neno': 'acha', 'tag': 'verb', 'word': 'stop', 'uwingi': ''},
#  {'neno': 'achali',
#   'tag': 'noun 9/10',
#   'word': '\x01ppetizer',
#   'uwingi': 'achali'},
#  {'neno': 'achali', 'tag': 'noun 9/10', 'word': 'chutney', 'uwingi': 'achali'},
#  {'neno': 'achali', 'tag': 'noun 9/10', 'word': 'relish', 'uwingi': 'achali'},
#  {'neno': 'achama', 'tag': 'verb', 'word': 'gasp', 'uwingi': ''},
#  {'neno': 'achama', 'tag': 'verb', 'word': 'open mouth wide', 'uwingi': ''},
#  {'neno': 'achana',
#   'tag': 'verb associative',
#   'word': 'be different',
#   'uwingi': ''},
#  {'neno': 'achana',
#   'tag': 'verb associative',
#   'word': 'diverge',
#   'uwingi': ''},
#  {'neno': 'achana',
#   'tag': 'verb associative',
#   'word': 'leave each other',
#   'uwingi': ''},
#  {'neno': 'achana',
#   'tag': 'verb associative',
#   'word': 'separate',
#   'uwingi': ''},
#  {'neno': 'achana',
#   'tag': 'verb associative',
#   'word': 'be separated',
#   'uwingi': ''},
#  {'neno': 'achana', 'tag': 'na verb reciprocal', 'word': 'part', 'uwingi': ''},
#  {'neno': 'na', 'tag': 'verb', 'word': 'break up', 'uwingi': ''},
#  {'neno': 'achari',
#   'tag': 'noun 9/10',
#   'word': '\x01ppetizer',
#   'uwingi': 'achari'},
#  {'neno': 'achari', 'tag': 'noun 9/10', 'word': 'chutney', 'uwingi': 'achari'},
#  {'neno': 'achari', 'tag': 'noun 9/10', 'word': 'relish', 'uwingi': 'achari'},
#  {'neno': 'achia',
#   'tag': 'verb applicative',
#   'word': 'bequeath',
#   'uwingi': ''},
#  {'neno': 'achia',
#   'tag': 'verb applicative',
#   'word': 'leave something to someone',
#   'uwingi': ''},
#  {'neno': 'achia',
#   'tag': 'verb applicative',
#   'word': 'leave for',
#   'uwingi': ''},
#  {'neno': 'achia',
#   'tag': 'verb applicative',
#   'word': 'let someone have something',
#   'uwingi': ''},
#  {'neno': 'achia', 'tag': 'verb applicative', 'word': 'let out', 'uwingi': ''},
#  {'neno': 'achia', 'tag': 'verb applicative', 'word': 'yield', 'uwingi': ''},
#  {'neno': 'achilia',
#   'tag': 'verb applicative',
#   'word': 'forgive',
#   'uwingi': ''},
#  {'neno': 'achilia',
#   'tag': 'verb applicative',
#   'word': 'pardon',
#   'uwingi': ''},
#  {'neno': 'achilia',
#   'tag': 'verb applicative',
#   'word': 'release',
#   'uwingi': ''},
#  {'neno': 'mbali', 'tag': 'verb applicative', 'word': 'abandon', 'uwingi': ''},
#  {'neno': 'mbali',
#   'tag': 'verb applicative',
#   'word': 'break off',
#   'uwingi': ''},
#  {'neno': 'mbali', 'tag': 'verb applicative', 'word': 'cease', 'uwingi': ''},
#  {'neno': 'mbali',
#   'tag': 'verb applicative',
#   'word': 'leave alone',
#   'uwingi': ''},
#  {'neno': 'achilika', 'tag': 'verb', 'word': 'be excusable', 'uwingi': ''},
#  {'neno': 'achilika', 'tag': 'verb', 'word': 'be pardonable', 'uwingi': ''},
#  {'neno': 'achilio',
#   'tag': 'noun 5/6',
#   'word': 'forgiveness',
#   'uwingi': 'maachilio'},
#  {'neno': 'achilio',
#   'tag': 'noun 5/6',
#   'word': 'pardon',
#   'uwingi': 'maachilio'},
#  {'neno': 'achiliwa', 'tag': 'verb', 'word': 'be released', 'uwingi': ''},
#  {'neno': 'achisha',
#   'tag': 'verb causative',
#   'word': 'cause to abandon',
#   'uwingi': ''},
#  {'neno': 'achisha',
#   'tag': 'verb causative',
#   'word': 'cause to divorce',
#   'uwingi': ''},
#  {'neno': 'achisha',
#   'tag': 'verb causative',
#   'word': 'cause to leave',
#   'uwingi': ''},
#  {'neno': 'achisha',
#   'tag': 'verb causative',
#   'word': 'wean (a child)',
#   'uwingi': ''},
#  {'neno': 'achwa', 'tag': 'verb', 'word': 'be left', 'uwingi': ''},
#  {'neno': 'ada', 'tag': 'noun 5/6', 'word': 'contribution', 'uwingi': 'maada'},
#  {'neno': 'ada', 'tag': 'noun 9/10', 'word': 'custom', 'uwingi': 'ada'},
#  {'neno': 'ada', 'tag': 'noun 9/10', 'word': '\x01ayment', 'uwingi': 'ada'},
#  {'neno': 'ada', 'tag': 'noun 9/10', 'word': 'fee', 'uwingi': 'ada'},
#  {'neno': 'ada',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01\x01\x01orthcoming)',
#   'uwingi': 'ada'},
#  {'neno': 'ada', 'tag': 'noun 9/10', 'word': 'habit', 'uwingi': 'ada'},
#  {'neno': 'ada', 'tag': 'noun 9/10', 'word': 'manner', 'uwingi': 'ada'},
#  {'neno': 'ada', 'tag': 'noun 5/6', 'word': 'payment', 'uwingi': 'maada'},
#  {'neno': 'harusi',
#   'tag': 'noun 5/6',
#   'word': '\x01resent',
#   'uwingi': 'maada'},
#  {'neno': 'mganga',
#   'tag': 'noun 9/10',
#   'word': "doctor'\x01ee",
#   'uwingi': 'ada'},
#  {'neno': 'shule', 'tag': 'noun 9/10', 'word': '\x01ee', 'uwingi': 'ada'},
#  {'neno': 'tu', 'tag': 'phrase', 'word': 'as is appropriate', 'uwingi': ''},
#  {'neno': 'tu', 'tag': 'phrase', 'word': 'as is fitting', 'uwingi': ''},
#  {'neno': 'adabu',
#   'tag': 'noun 9/10',
#   'word': '\x01ehavior',
#   'uwingi': 'adabu'},
#  {'neno': 'adabu',
#   'tag': 'noun 9/10',
#   'word': 'consideration',
#   'uwingi': 'adabu'},
#  {'neno': 'adabu', 'tag': 'noun 9/10', 'word': 'courtesy', 'uwingi': 'adabu'},
#  {'neno': 'adabu', 'tag': 'noun 9/10', 'word': 'manners', 'uwingi': 'adabu'},
#  {'neno': 'adabu',
#   'tag': 'noun 9/10',
#   'word': 'politeness',
#   'uwingi': 'adabu'},
#  {'neno': 'Adamu', 'tag': 'noun 1', 'word': 'Adam', 'uwingi': ''},
#  {'neno': 'adawa', 'tag': 'noun 9/10', 'word': 'enmity', 'uwingi': 'adawa'},
#  {'neno': 'adawa', 'tag': 'noun 9/10', 'word': 'hostility', 'uwingi': 'adawa'},
#  {'neno': 'adawa', 'tag': 'noun 9/10', 'word': 'illwill', 'uwingi': 'adawa'},
#  {'neno': 'Aden', 'tag': 'noun', 'word': 'Aden (city)', 'uwingi': ''},
#  {'neno': 'adesi', 'tag': 'noun 9/10', 'word': 'lentil', 'uwingi': 'adesi'},
#  {'neno': 'adha', 'tag': 'noun 9/10', 'word': 'discomfort', 'uwingi': 'adha'},
#  {'neno': 'adha', 'tag': 'noun 9/10', 'word': 'trouble', 'uwingi': 'adha'},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'chastise', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'persecute', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'punish', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'chastise', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'persecute', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'punish', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'chastise', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'persecute', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'verb', 'word': 'punish', 'uwingi': ''},
#  {'neno': 'adhabu', 'tag': 'noun 9/10', 'word': 'pain', 'uwingi': 'adhabu'},
#  {'neno': 'adhabu', 'tag': 'noun 9/10', 'word': 'penalty', 'uwingi': 'adhabu'},
#  {'neno': 'adhabu',
#   'tag': 'noun 9/10',
#   'word': 'persecution',
#   'uwingi': 'adhabu'},
#  {'neno': 'adhabu',
#   'tag': 'noun 9/10',
#   'word': 'punishment',
#   'uwingi': 'adhabu'},
#  {'neno': 'adhabu', 'tag': 'noun 9/10', 'word': 'pursuit', 'uwingi': 'adhabu'},
#  {'neno': 'adhabu', 'tag': 'noun 9/10', 'word': 'torment', 'uwingi': 'adhabu'},
#  {'neno': 'adhama',
#   'tag': 'noun 9/10',
#   'word': 'authority',
#   'uwingi': 'adhama'},
#  {'neno': 'adhama',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01\x01uezzin',
#   'uwingi': 'adhama'},
#  {'neno': 'adhama', 'tag': 'noun 9/10', 'word': 'dignity', 'uwingi': 'adhama'},
#  {'neno': 'adhama', 'tag': 'noun 9/10', 'word': 'fame', 'uwingi': 'adhama'},
#  {'neno': 'adhama', 'tag': 'noun 9/10', 'word': 'glory', 'uwingi': 'adhama'},
#  {'neno': 'adhama',
#   'tag': 'noun 9/10',
#   'word': 'grandeur',
#   'uwingi': 'adhama'},
#  {'neno': 'adhama',
#   'tag': 'noun 9/10',
#   'word': 'greatness',
#   'uwingi': 'adhama'},
#  {'neno': 'adhama', 'tag': 'noun 9/10', 'word': 'honor', 'uwingi': 'adhama'},
#  {'neno': 'adhama', 'tag': 'noun 9/10', 'word': 'pomp', 'uwingi': 'adhama'},
#  {'neno': 'adhama', 'tag': 'noun 9/10', 'word': 'power', 'uwingi': 'adhama'},
#  {'neno': 'adhama',
#   'tag': 'noun 9/10',
#   'word': 'splendor',
#   'uwingi': 'adhama'},
#  {'neno': 'adana', 'tag': 'verb', 'word': 'call to prayer', 'uwingi': ''},
#  {'neno': 'adhana',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01\x01uezzin',
#   'uwingi': 'adhana'},
#  {'neno': 'adhibika', 'tag': 'verb', 'word': 'be punished', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'annoy', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'chastise', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'harass', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'pass judgement', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'molest', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'cause pain', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'punish', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'sentence', 'uwingi': ''},
#  {'neno': 'adhibisha', 'tag': 'verb', 'word': 'torment', 'uwingi': ''},
#  {'neno': 'adhibiwa', 'tag': 'verb', 'word': 'be punished', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'annoy', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'chastise', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'harass', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'pass judgement', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'molest', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'cause pain', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'punish', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'sentence', 'uwingi': ''},
#  {'neno': 'adhibu', 'tag': 'verb', 'word': 'torment', 'uwingi': ''},
#  {'neno': 'adhima',
#   'tag': 'noun 9/10',
#   'word': 'authority',
#   'uwingi': 'adhima'},
#  {'neno': 'adhima', 'tag': 'noun 9/10', 'word': 'dignity', 'uwingi': 'adhima'},
#  {'neno': 'adhima', 'tag': 'noun 9/10', 'word': 'fame', 'uwingi': 'adhima'},
#  {'neno': 'adhima',
#   'tag': 'noun 9/10',
#   'word': 'grandeur',
#   'uwingi': 'adhima'},
#  {'neno': 'adhima',
#   'tag': 'noun 9/10',
#   'word': 'greatness',
#   'uwingi': 'adhima'},
#  {'neno': 'adhima', 'tag': 'noun 9/10', 'word': 'pomp', 'uwingi': 'adhima'},
#  {'neno': 'adhima', 'tag': 'noun 9/10', 'word': 'power', 'uwingi': 'adhima'},
#  {'neno': 'adhima',
#   'tag': 'noun 9/10',
#   'word': 'splendor',
#   'uwingi': 'adhima'},
#  {'neno': 'adhimia',
#   'tag': 'verb applicative',
#   'word': 'praise someone',
#   'uwingi': ''},
#  {'neno': 'adhimisha',
#   'tag': 'verb causative',
#   'word': 'celebrate',
#   'uwingi': ''},
#  {'neno': 'adhimisha', 'tag': 'verb causative', 'word': 'exalt', 'uwingi': ''},
#  {'neno': 'adhimisha',
#   'tag': 'verb causative',
#   'word': 'glorify',
#   'uwingi': ''},
#  {'neno': 'adhimisha', 'tag': 'verb causative', 'word': 'honor', 'uwingi': ''},
#  {'neno': 'adhimisha',
#   'tag': 'verb causative',
#   'word': 'magnify',
#   'uwingi': ''},
#  {'neno': 'adhimisha',
#   'tag': 'verb causative',
#   'word': 'praise',
#   'uwingi': ''},
#  {'neno': 'adhimisho',
#   'tag': 'noun 5/6',
#   'word': 'celebration',
#   'uwingi': 'maadhimisho'},
#  {'neno': 'adhimisho',
#   'tag': 'noun 5/6',
#   'word': 'ceremony',
#   'uwingi': 'maadhimisho'},
#  {'neno': 'adhimisho',
#   'tag': 'noun 5/6',
#   'word': 'solemnity',
#   'uwingi': 'maadhimisho'},
#  {'neno': 'adhimu', 'tag': 'verb', 'word': 'celebrate', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'verb', 'word': 'exalt', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'verb', 'word': 'glorify', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'verb', 'word': 'honor', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'verb', 'word': 'magnify', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'verb', 'word': 'praise', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'adjective', 'word': 'great', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'adjective', 'word': 'important', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'adjective', 'word': 'significant', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'adverb', 'word': 'greatly', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'adverb', 'word': 'importantly', 'uwingi': ''},
#  {'neno': 'adhimu', 'tag': 'adverb', 'word': 'significantly', 'uwingi': ''},
#  {'neno': 'adhini',
#   'tag': 'verb',
#   'word': 'call to prayer (Islam)',
#   'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'criticize', 'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'defame', 'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'degrade', 'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'find fault with', 'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'humiliate', 'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'reprove', 'uwingi': ''},
#  {'neno': 'adhiri', 'tag': 'verb', 'word': 'slander', 'uwingi': ''},
#  {'neno': 'adhuhuri',
#   'tag': 'noun 9/10',
#   'word': 'midday',
#   'uwingi': 'adhuhuri'},
#  {'neno': 'adhuuri',
#   'tag': 'noun 9/10',
#   'word': "\x01\x01\x01\x01 o'clock)",
#   'uwingi': 'adhuuri'},
#  {'neno': 'adi', 'tag': 'verb', 'word': 'accompany', 'uwingi': ''},
#  {'neno': 'adi', 'tag': 'verb', 'word': 'escort', 'uwingi': ''},
#  {'neno': 'adi',
#   'tag': 'verb',
#   'word': 'go part of the way with s',
#   'uwingi': ''},
#  {'neno': 'adia', 'tag': 'noun 9/10', 'word': '\x01ift', 'uwingi': 'adia'},
#  {'neno': 'adia', 'tag': 'noun 9/10', 'word': 'present', 'uwingi': 'adia'},
#  {'neno': 'adibisha',
#   'tag': 'verb causative',
#   'word': 'cause to be brought up',
#   'uwingi': ''},
#  {'neno': 'adibisha',
#   'tag': 'verb causative',
#   'word': 'cause to be educated',
#   'uwingi': ''},
#  {'neno': 'adibisha',
#   'tag': 'verb causative',
#   'word': 'cause to be taught good manners',
#   'uwingi': ''},
#  {'neno': 'adibisha',
#   'tag': 'verb causative',
#   'word': 'train in good manners',
#   'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'verb', 'word': 'bring up', 'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'verb', 'word': 'educate', 'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'verb', 'word': 'teach good manners', 'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'adjective', 'word': 'courteous', 'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'adjective', 'word': 'gracious', 'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'adjective', 'word': 'polite', 'uwingi': ''},
#  {'neno': 'adibu', 'tag': 'adjective', 'word': 'wellbred', 'uwingi': ''},
#  {'neno': 'yako', 'tag': 'phrase', 'word': 'Behave yourself!', 'uwingi': ''},
#  {'neno': 'adili',
#   'tag': 'verb',
#   'word': 'conduct oneself well',
#   'uwingi': ''},
#  {'neno': 'adili', 'tag': 'verb', 'word': 'be impartial', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'verb', 'word': 'be just', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'adjective', 'word': 'correct', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'adjective', 'word': 'honest', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'adjective', 'word': 'impartial', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'adjective', 'word': 'just', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'adjective', 'word': 'right', 'uwingi': ''},
#  {'neno': 'adili', 'tag': 'adjective', 'word': 'righteous', 'uwingi': ''},
#  {'neno': 'adili',
#   'tag': 'adjective',
#   'word': 'straightforward',
#   'uwingi': ''},
#  {'neno': 'adili',
#   'tag': 'noun 5/6',
#   'word': '\x01onduct',
#   'uwingi': 'maadili'},
#  {'neno': 'adili', 'tag': 'noun 5/6', 'word': 'ethics', 'uwingi': 'maadili'},
#  {'neno': 'adili',
#   'tag': 'noun 5/6',
#   'word': '\x01onduct',
#   'uwingi': 'maadili'},
#  {'neno': 'adili',
#   'tag': 'noun 5/6',
#   'word': 'impartiality',
#   'uwingi': 'maadili'},
#  {'neno': 'adili', 'tag': 'noun 5/6', 'word': 'justice', 'uwingi': 'maadili'},
#  {'neno': 'adili', 'tag': 'noun 5/6', 'word': 'morality', 'uwingi': 'maadili'},
#  {'neno': 'adili', 'tag': 'noun 5/6', 'word': 'morals', 'uwingi': 'maadili'},
#  {'neno': 'adilifu', 'tag': 'adjective', 'word': 'correct', 'uwingi': ''},
#  {'neno': 'adilifu', 'tag': 'adjective', 'word': 'honest', 'uwingi': ''},
#  {'neno': 'adilifu', 'tag': 'adjective', 'word': 'impartial', 'uwingi': ''},
#  {'neno': 'adilifu', 'tag': 'adjective', 'word': 'just', 'uwingi': ''},
#  {'neno': 'adilifu', 'tag': 'adjective', 'word': 'right', 'uwingi': ''},
#  {'neno': 'adilifu', 'tag': 'adjective', 'word': 'righteous', 'uwingi': ''},
#  {'neno': 'adilifu',
#   'tag': 'adjective',
#   'word': 'straightforward',
#   'uwingi': ''},
#  {'neno': 'adilisha',
#   'tag': 'verb',
#   'word': 'cause to be moral',
#   'uwingi': ''},
#  {'neno': 'adilisha', 'tag': 'verb', 'word': 'teach morality', 'uwingi': ''},
#  {'neno': 'adilisha',
#   'tag': 'verb',
#   'word': 'cause to be righteous',
#   'uwingi': ''},
#  {'neno': 'adilisha',
#   'tag': 'verb',
#   'word': 'teach good conduct',
#   'uwingi': ''},
#  {'neno': 'adilisha',
#   'tag': 'verb',
#   'word': 'teach right conduct',
#   'uwingi': ''},
#  {'neno': 'adimika', 'tag': 'verb', 'word': 'be obtainable', 'uwingi': ''},
#  {'neno': 'adimika', 'tag': 'verb', 'word': 'be rare', 'uwingi': ''},
#  {'neno': 'adimika', 'tag': 'verb', 'word': 'be scarce', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'deficient', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'faulty', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'inadequate', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'insufficient', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'rare', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'scarce', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'unobtainable', 'uwingi': ''},
#  {'neno': 'adimu', 'tag': 'adjective', 'word': 'unsatisfactory', 'uwingi': ''},
#  {'neno': 'adinasi',
#   'tag': 'noun 9/10an',
#   'word': '\x01an',
#   'uwingi': 'adinasi'},
#  {'neno': 'adinasi',
#   'tag': 'noun 9/10an',
#   'word': '\x01\x01\x01irth',
#   'uwingi': 'adinasi'},
#  {'neno': 'admeli',
#   'tag': 'noun 9/10an',
#   'word': 'admiral',
#   'uwingi': 'admeli'},
#  {'neno': 'admirali',
#   'tag': 'noun 9/10an',
#   'word': 'admiral',
#   'uwingi': 'admirali'},
#  {'neno': 'adua',
#   'tag': 'verb',
#   'word': 'prepare magical charms (against the evil eye)',
#   'uwingi': ''},
#  {'neno': 'adua', 'tag': 'verb', 'word': 'make offerings', 'uwingi': ''},
#  {'neno': 'adua', 'tag': 'verb', 'word': 'make sacrifices', 'uwingi': ''},
#  {'neno': 'adui', 'tag': 'noun 5/6an', 'word': 'enemy', 'uwingi': 'maadui'},
#  {'neno': 'adui', 'tag': 'noun 5/6an', 'word': 'foe', 'uwingi': 'maadui'},
#  {'neno': 'adui', 'tag': 'noun 5/6an', 'word': 'opponent', 'uwingi': 'maadui'},
#  {'neno': 'aenzi', 'tag': 'verb', 'word': 'exalt', 'uwingi': ''},
#  {'neno': 'aenzi', 'tag': 'verb', 'word': 'glorify', 'uwingi': ''},
#  {'neno': 'aenzi',
#   'tag': 'verb',
#   'word': 'inaugurate (as a ruler)',
#   'uwingi': ''},
#  {'neno': 'aenzi', 'tag': 'verb', 'word': 'install', 'uwingi': ''},
#  {'neno': 'aenzi', 'tag': 'verb', 'word': 'invest with power', 'uwingi': ''},
#  {'neno': 'aenzi', 'tag': 'noun 9/10', 'word': 'dominion', 'uwingi': 'aenzi'},
#  {'neno': 'aenzi', 'tag': 'noun 9/10', 'word': 'power', 'uwingi': 'aenzi'},
#  {'neno': 'aenzi', 'tag': 'noun 9/10', 'word': 'rule', 'uwingi': 'aenzi'},
#  {'neno': 'aenzi',
#   'tag': 'noun 9/10',
#   'word': 'sovereignty',
#   'uwingi': 'aenzi'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'accident', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': '\x01uck', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'calamity', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'catastrophe', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'damage', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'danger', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'disaster', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'horror', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'injury', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'injustice', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'menace', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'misfortune', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'mishap', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'peril', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'terror', 'uwingi': 'maafa'},
#  {'neno': 'afa', 'tag': 'noun 5/6', 'word': 'threat', 'uwingi': 'maafa'},
#  {'neno': 'afadhali', 'tag': 'adverb', 'word': 'better', 'uwingi': ''},
#  {'neno': 'afadhali', 'tag': 'adverb', 'word': 'preferable', 'uwingi': ''},
#  {'neno': 'afadhali', 'tag': 'adverb', 'word': 'preferably', 'uwingi': ''},
#  {'neno': 'afadhali', 'tag': 'adverb', 'word': 'rather', 'uwingi': ''},
#  {'neno': 'afande',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01\x01olice',
#   'uwingi': 'afande'},
#  {'neno': 'afdhali', 'tag': 'adverb', 'word': 'better', 'uwingi': ''},
#  {'neno': 'afdhali', 'tag': 'adverb', 'word': 'particularly', 'uwingi': ''},
#  {'neno': 'afdhali', 'tag': 'adverb', 'word': 'preferable', 'uwingi': ''},
#  {'neno': 'afdhali', 'tag': 'adverb', 'word': 'preferably', 'uwingi': ''},
#  {'neno': 'afdhali', 'tag': 'adverb', 'word': 'rather', 'uwingi': ''},
#  {'neno': 'afendi',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01ank)',
#   'uwingi': 'afendi'},
#  {'neno': 'afia', 'tag': 'noun 9/10', 'word': 'health', 'uwingi': 'afia'},
#  {'neno': 'afia', 'tag': 'noun 9/10', 'word': 'strength', 'uwingi': 'afia'},
#  {'neno': 'afia', 'tag': 'noun 9/10', 'word': 'vigor', 'uwingi': 'afia'},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'agree together',
#   'uwingi': ''},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'come to an agreement',
#   'uwingi': ''},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'compromise',
#   'uwingi': ''},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'make a contract',
#   'uwingi': ''},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'be reconciled',
#   'uwingi': ''},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'make a settlement',
#   'uwingi': ''},
#  {'neno': 'afikana',
#   'tag': 'verb associative',
#   'word': 'come to an understanding',
#   'uwingi': ''},
#  {'neno': 'afikanisha',
#   'tag': 'verb causative',
#   'word': 'appease',
#   'uwingi': ''},
#  {'neno': 'afikanisha',
#   'tag': 'verb causative',
#   'word': 'conciliate',
#   'uwingi': ''},
#  {'neno': 'afikanisha',
#   'tag': 'verb causative',
#   'word': 'reconcile',
#   'uwingi': ''},
#  {'neno': 'afikanisha',
#   'tag': 'verb causative',
#   'word': 'satisfy',
#   'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'agree', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'agree (with)', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'appease', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'assent', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'correspond', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'fit', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'be fitting', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'be the same as', 'uwingi': ''},
#  {'neno': 'afiki', 'tag': 'verb', 'word': 'satisfy', 'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'agree together',
#   'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'come to an agreement',
#   'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'compromise',
#   'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'make a contract',
#   'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'be reconciled',
#   'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'make a settlement',
#   'uwingi': ''},
#  {'neno': 'afikiana',
#   'tag': 'verb associative',
#   'word': 'come to an understanding',
#   'uwingi': ''},
#  {'neno': 'afikiano',
#   'tag': 'noun 5/6',
#   'word': 'agreement',
#   'uwingi': 'maafikiano'},
#  {'neno': 'afikiano',
#   'tag': 'noun 5/6',
#   'word': 'compromise',
#   'uwingi': 'maafikiano'},
#  {'neno': 'afikiano',
#   'tag': 'noun 5/6',
#   'word': 'pact',
#   'uwingi': 'maafikiano'},
#  {'neno': 'afikiano',
#   'tag': 'noun 5/6',
#   'word': 'settlement',
#   'uwingi': 'maafikiano'},
#  {'neno': 'afiriti',
#   'tag': 'noun 9/10an',
#   'word': '\x01enius',
#   'uwingi': 'afiriti'},
#  {'neno': 'afiriti',
#   'tag': 'noun 9/10an',
#   'word': '\x01erson',
#   'uwingi': 'afiriti'},
#  {'neno': 'afisa',
#   'tag': 'noun 5/6an',
#   'word': '\x01fficer',
#   'uwingi': 'maafisa'},
#  {'neno': 'afisa',
#   'tag': 'noun 5/6an',
#   'word': 'officer',
#   'uwingi': 'maafisa'},
#  {'neno': 'afisa',
#   'tag': 'noun 5/6an',
#   'word': 'official',
#   'uwingi': 'maafisa'},
#  {'neno': 'afisi', 'tag': 'noun 9/10', 'word': 'bureau', 'uwingi': 'afisi'},
#  {'neno': 'afisi',
#   'tag': 'noun 9/10',
#   'word': 'department',
#   'uwingi': 'afisi'},
#  {'neno': 'afisi', 'tag': 'noun 9/10', 'word': 'office', 'uwingi': 'afisi'},
#  {'neno': 'afiuni', 'tag': 'noun 9/10', 'word': 'opium', 'uwingi': 'afiuni'},
#  {'neno': 'Afrika', 'tag': 'noun 9', 'word': 'Africa', 'uwingi': ''},
#  {'neno': 'Kati', 'tag': 'noun 9', 'word': 'Central Africa', 'uwingi': ''},
#  {'neno': 'afrikanaizesheni',
#   'tag': 'noun 9',
#   'word': 'Africanization',
#   'uwingi': ''},
#  {'neno': 'afriti', 'tag': 'noun 9/10an', 'word': 'devil', 'uwingi': 'afriti'},
#  {'neno': 'afriti',
#   'tag': 'noun 5/6an',
#   'word': '\x01enius',
#   'uwingi': 'afriti'},
#  {'neno': 'afriti',
#   'tag': 'noun 9/10an',
#   'word': '\x01erson',
#   'uwingi': 'afriti'},
#  {'neno': 'afriti',
#   'tag': 'noun 9/10an',
#   'word': '\x01pirit',
#   'uwingi': 'afriti'},
#  {'neno': 'afriti',
#   'tag': 'noun 9/10an',
#   'word': '\x01erson',
#   'uwingi': 'afriti'},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'cure', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'defend', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'deliver from calamity', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'forgive', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'free', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'guard', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'heal', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'help', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'liberate', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'pardon', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'protect', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'release', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'verb', 'word': 'save', 'uwingi': ''},
#  {'neno': 'afu', 'tag': 'noun 9/10', 'word': 'defense', 'uwingi': 'afu'},
#  {'neno': 'afu',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01alamity',
#   'uwingi': 'afu'},
#  {'neno': 'afu',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01asmine',
#   'uwingi': 'afu'},
#  {'neno': 'afu', 'tag': 'noun 9/10', 'word': '\x01\x01wild)', 'uwingi': 'afu'},
#  {'neno': 'afu', 'tag': 'noun 9/10', 'word': 'liberation', 'uwingi': 'afu'},
#  {'neno': 'afu', 'tag': 'noun 9/10', 'word': 'protection', 'uwingi': 'afu'},
#  {'neno': 'afu', 'tag': 'noun 9/10', 'word': 'redemption', 'uwingi': 'afu'},
#  {'neno': 'afu', 'tag': 'noun 9/10', 'word': 'salvation', 'uwingi': 'afu'},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'cure', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'defend', 'uwingi': ''},
#  {'neno': 'afua',
#   'tag': 'verb',
#   'word': 'deliver from calamity',
#   'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'forgive', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'free', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'guard', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'heal', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'liberate', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'pardon', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'protect', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'release', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'verb', 'word': 'save', 'uwingi': ''},
#  {'neno': 'afua', 'tag': 'noun 9/10', 'word': 'defense', 'uwingi': 'afua'},
#  {'neno': 'afua', 'tag': 'noun 9/10', 'word': 'liberation', 'uwingi': 'afua'},
#  {'neno': 'afua', 'tag': 'noun 9/10', 'word': 'protection', 'uwingi': 'afua'},
#  {'neno': 'afua', 'tag': 'noun 9/10', 'word': 'redemption', 'uwingi': 'afua'},
#  {'neno': 'afua', 'tag': 'noun 9/10', 'word': 'salvation', 'uwingi': 'afua'},
#  {'neno': 'afudhali', 'tag': 'adverb', 'word': 'better', 'uwingi': ''},
#  {'neno': 'afudhali', 'tag': 'adverb', 'word': 'particularly', 'uwingi': ''},
#  {'neno': 'afudhali', 'tag': 'adverb', 'word': 'preferably', 'uwingi': ''},
#  {'neno': 'afudhali', 'tag': 'adverb', 'word': 'rather', 'uwingi': ''},
#  {'neno': 'afueni', 'tag': 'noun', 'word': 'convalescent leave', 'uwingi': ''},
#  {'neno': 'afya', 'tag': 'verb', 'word': 'put on oath', 'uwingi': ''},
#  {'neno': 'afya', 'tag': 'verb', 'word': 'sneeze', 'uwingi': ''},
#  {'neno': 'afya', 'tag': 'noun 9/10', 'word': 'health', 'uwingi': 'afya'},
#  {'neno': 'afya', 'tag': 'noun 9/10', 'word': 'strength', 'uwingi': 'afya'},
#  {'neno': 'afya', 'tag': 'noun 9/10', 'word': 'vigor', 'uwingi': 'afya'},
#  {'neno': 'Afya', 'tag': 'phrase', 'word': 'good health', 'uwingi': ''},
#  {'neno': 'afya',
#   'tag': 'phrase',
#   'word': 'response to a sneeze',
#   'uwingi': ''},
#  {'neno': 'afyuni', 'tag': 'noun 9/10', 'word': 'opium', 'uwingi': 'afyuni'},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'agree', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'agree with', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'come to an agreement', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'make a contract', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'destroy', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'say goodbye', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'leave', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': "take one's leave", 'uwingi': ''},
#  {'neno': 'die', 'tag': 'euphemism', 'word': '', 'uwingi': ''},
#  {'neno': 'aga', 'tag': 'verb', 'word': 'take leave of', 'uwingi': ''},
#  {'neno': 'Agami', 'tag': 'noun', 'word': 'pl (sing', 'uwingi': ''},
#  {'neno': 'Agami', 'tag': 'noun', 'word': 'pl (sing', 'uwingi': ''},
#  {'neno': 'Agami', 'tag': 'noun', 'word': 'Iran', 'uwingi': ''},
#  {'neno': 'agana', 'tag': 'verb', 'word': 'agree', 'uwingi': ''},
#  {'neno': 'agana', 'tag': 'verb', 'word': 'make an agreement', 'uwingi': ''},
#  {'neno': 'agana', 'tag': 'verb', 'word': 'make a contract', 'uwingi': ''},
#  {'neno': 'agana',
#   'tag': 'verb',
#   'word': 'say goodbye (to each other)',
#   'uwingi': ''},
#  {'neno': 'agana',
#   'tag': 'verb',
#   'word': 'take leave of each other (for a long period)',
#   'uwingi': ''},
#  {'neno': 'agana',
#   'tag': 'verb reciprocal',
#   'word': 'make a pact',
#   'uwingi': ''},
#  {'neno': 'agana',
#   'tag': 'verb reciprocal',
#   'word': 'take leave of each other',
#   'uwingi': ''},
#  {'neno': 'buriani',
#   'tag': 'verb',
#   'word': 'bid each other a final farewell',
#   'uwingi': ''},
#  {'neno': 'agano',
#   'tag': 'noun 5/6',
#   'word': 'agreement',
#   'uwingi': 'maagano'},
#  {'neno': 'agano',
#   'tag': 'noun 5/6',
#   'word': 'arrangement',
#   'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'contract', 'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'covenant', 'uwingi': 'maagano'},
#  {'neno': 'agano',
#   'tag': 'noun 5/6',
#   'word': 'departure',
#   'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'farewell', 'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'pact', 'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'parting', 'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'promise', 'uwingi': 'maagano'},
#  {'neno': 'agano',
#   'tag': 'noun 5/6',
#   'word': 'settlement',
#   'uwingi': 'maagano'},
#  {'neno': 'agano',
#   'tag': 'noun 5/6',
#   'word': 'testament',
#   'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'treaty', 'uwingi': 'maagano'},
#  {'neno': 'agano',
#   'tag': 'noun 5/6',
#   'word': 'understanding',
#   'uwingi': 'maagano'},
#  {'neno': 'agano', 'tag': 'noun 5/6', 'word': 'vow', 'uwingi': 'maagano'},
#  {'neno': 'Kale', 'tag': 'phrase', 'word': 'Old Testament', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'chiefly', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'mainly', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'more often', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'mostly', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'ordinarily', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'as a rule', 'uwingi': ''},
#  {'neno': 'aghalabu', 'tag': 'adverb', 'word': 'usually', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'chiefly', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'mainly', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'more often', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'mostly', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'ordinarily', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'as a rule', 'uwingi': ''},
#  {'neno': 'aghlabu', 'tag': 'adverb', 'word': 'usually', 'uwingi': ''},
#  {'neno': 'agia', 'tag': 'verb applicative', 'word': 'befit', 'uwingi': ''},
#  {'neno': 'agia', 'tag': 'verb applicative', 'word': 'suit', 'uwingi': ''},
#  {'neno': 'agiza', 'tag': 'verb causative', 'word': 'charge', 'uwingi': ''},
#  {'neno': 'agiza',
#   'tag': 'verb causative',
#   'word': 'commission',
#   'uwingi': ''},
#  {'neno': 'agiza', 'tag': 'verb causative', 'word': 'direct', 'uwingi': ''},
#  {'neno': 'agiza', 'tag': 'verb causative', 'word': 'instruct', 'uwingi': ''},
#  {'neno': 'agiza',
#   'tag': 'verb causative',
#   'word': 'give instructions',
#   'uwingi': ''},
#  {'neno': 'agiza', 'tag': 'verb causative', 'word': 'order', 'uwingi': ''},
#  {'neno': 'agizia',
#   'tag': 'verb applicative',
#   'word': 'order for',
#   'uwingi': ''},
#  {'neno': 'agizo',
#   'tag': 'noun 5/6',
#   'word': 'commission',
#   'uwingi': 'maagizo'},
#  {'neno': 'agizo',
#   'tag': 'noun 5/6',
#   'word': 'direction',
#   'uwingi': 'maagizo'},
#  {'neno': 'agizo',
#   'tag': 'noun 5/6',
#   'word': 'directive',
#   'uwingi': 'maagizo'},
#  {'neno': 'agizo',
#   'tag': 'noun 5/6',
#   'word': 'instruction',
#   'uwingi': 'maagizo'},
#  {'neno': 'agizo', 'tag': 'noun 5/6', 'word': 'order', 'uwingi': 'maagizo'},
#  {'neno': 'agizo',
#   'tag': 'noun 5/6',
#   'word': 'regulation',
#   'uwingi': 'maagizo'},
#  {'neno': 'agizwa', 'tag': 'verb', 'word': 'be ordered', 'uwingi': ''},
#  {'neno': 'Agosti', 'tag': 'noun 9', 'word': 'August', 'uwingi': ''},
#  {'neno': 'agua', 'tag': 'verb', 'word': 'divine', 'uwingi': ''},
#  {'neno': 'agua', 'tag': 'verb', 'word': 'foretell', 'uwingi': ''},
#  {'neno': 'agua', 'tag': 'verb', 'word': 'predict', 'uwingi': ''},
#  {'neno': 'agua', 'tag': 'verb', 'word': 'prophesy', 'uwingi': ''},
#  {'neno': 'agua', 'tag': 'verb', 'word': 'treat (usu', 'uwingi': ''},
#  {'neno': 'agulia',
#   'tag': 'verb applicative',
#   'word': 'predict',
#   'uwingi': ''},
#  {'neno': 'agulia',
#   'tag': 'verb applicative',
#   'word': 'prophesy',
#   'uwingi': ''},
#  {'neno': 'aguliwa', 'tag': 'verb', 'word': 'be predicted', 'uwingi': ''},
#  {'neno': 'aguzi',
#   'tag': 'noun 5/6',
#   'word': '\x01\x01\x01 spell',
#   'uwingi': 'maaguzi'},
#  {'neno': 'aguzi',
#   'tag': 'noun 5/6',
#   'word': '\x01\x01 \x01\x01men)',
#   'uwingi': 'maaguzi'},
#  {'neno': 'aguzi', 'tag': 'noun 5/6', 'word': 'medicine', 'uwingi': 'maaguzi'},
#  {'neno': 'aguzi',
#   'tag': 'noun 5/6',
#   'word': 'prediction',
#   'uwingi': 'maaguzi'},
#  {'neno': 'aguzi', 'tag': 'noun 5/6', 'word': 'prophesy', 'uwingi': 'maaguzi'},
#  {'neno': 'aguzi', 'tag': 'noun 5/6', 'word': 'remedy', 'uwingi': 'maaguzi'},
#  {'neno': 'ah', 'tag': 'interjection', 'word': 'expresses joy', 'uwingi': ''},
#  {'neno': 'ah', 'tag': 'interjection', 'word': 'expresses pain', 'uwingi': ''},
#  {'neno': 'ah',
#   'tag': 'interjection',
#   'word': 'expresses surprise',
#   'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'keep a vow', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'make a promise', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'make a promise', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'keep a promise', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'keep a vow', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'keep a vow', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'break a promise', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'verb', 'word': 'break a vow', 'uwingi': ''},
#  {'neno': 'ahadi', 'tag': 'noun 9/10', 'word': 'agreement', 'uwingi': 'ahadi'},
#  {'neno': 'ahadi', 'tag': 'noun 9/10', 'word': 'covenant', 'uwingi': 'ahadi'},
#  {'neno': 'ahadi',
#   'tag': 'noun 9/10',
#   'word': 'obligation',
#   'uwingi': 'ahadi'},
#  {'neno': 'ahadi', 'tag': 'noun 9/10', 'word': 'promise', 'uwingi': 'ahadi'},
#  {'neno': 'ahadi', 'tag': 'noun 9/10', 'word': 'vow', 'uwingi': 'ahadi'},
#  {'neno': 'ahali', 'tag': 'noun 9/10an', 'word': 'family', 'uwingi': 'ahali'},
#  {'neno': 'ahali',
#   'tag': 'noun 9/10an',
#   'word': 'relations',
#   'uwingi': 'ahali'},
#  {'neno': 'ahali',
#   'tag': 'noun 9/10an',
#   'word': '\x01distant)',
#   'uwingi': 'ahali'},
#  {'neno': 'and', 'tag': 'other', 'word': '', 'uwingi': ''},
#  {'neno': 'ahali', 'tag': 'noun 9/10an', 'word': 'wife', 'uwingi': 'ahali'},
#  {'neno': 'ahera', 'tag': 'noun 9/10', 'word': 'afterlife', 'uwingi': 'ahera'},
#  {'neno': 'ahera', 'tag': 'noun 9/10', 'word': 'hereafter', 'uwingi': 'ahera'},
#  {'neno': 'die', 'tag': 'figurative', 'word': '', 'uwingi': ''},
#  {'neno': 'ahera',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01ome',
#   'uwingi': 'ahera'},
#  {'neno': 'ahera', 'tag': 'noun 9/10', 'word': '\x01orld', 'uwingi': 'ahera'},
#  {'neno': 'aheri', 'tag': 'noun 9/10', 'word': 'border', 'uwingi': 'aheri'},
#  {'neno': 'aheri', 'tag': 'noun 9/10', 'word': 'end', 'uwingi': 'aheri'},
#  {'neno': 'aheri', 'tag': 'noun 9/10', 'word': 'limit', 'uwingi': 'aheri'},
#  {'neno': 'ahi', 'tag': 'noun 9/10an', 'word': 'brother', 'uwingi': 'ahi'},
#  {'neno': 'ahi', 'tag': 'noun 9/10an', 'word': '\x01eople', 'uwingi': 'ahi'},
#  {'neno': 'ahi', 'tag': 'noun 9/10an', 'word': 'friend', 'uwingi': 'ahi'},
#  {'neno': 'ahi', 'tag': 'noun 9/10an', 'word': 'rabble', 'uwingi': 'ahi'},
#  {'neno': 'ahidi', 'tag': 'verb', 'word': 'agree', 'uwingi': ''},
#  {'neno': 'ahidi', 'tag': 'verb', 'word': 'promise', 'uwingi': ''},
#  {'neno': 'ahidi', 'tag': 'verb', 'word': 'vow', 'uwingi': ''},
#  {'neno': 'ahidiana',
#   'tag': 'verb',
#   'word': 'promise one another',
#   'uwingi': ''},
#  {'neno': 'ahidiwa',
#   'tag': 'verb passive',
#   'word': 'be promised',
#   'uwingi': ''},
#  {'neno': 'ahiri', 'tag': 'verb', 'word': 'delay', 'uwingi': ''},
#  {'neno': 'ahiri', 'tag': 'verb', 'word': 'hesitate', 'uwingi': ''},
#  {'neno': 'ahiri', 'tag': 'verb', 'word': 'be postponed', 'uwingi': ''},
#  {'neno': 'ahiri', 'tag': 'verb', 'word': 'procrastinate', 'uwingi': ''},
#  {'neno': 'ahiri', 'tag': 'verb', 'word': 'be put off', 'uwingi': ''},
#  {'neno': 'ahirisha',
#   'tag': 'verb causative',
#   'word': 'postpone',
#   'uwingi': ''},
#  {'neno': 'ahirisha',
#   'tag': 'verb causative',
#   'word': 'put off',
#   'uwingi': ''},
#  {'neno': 'ahiriwa',
#   'tag': 'verb passive',
#   'word': 'be postponed',
#   'uwingi': ''},
#  {'neno': 'ahli', 'tag': 'noun 9/10an', 'word': 'family', 'uwingi': 'ahli'},
#  {'neno': 'ahli', 'tag': 'noun 9/10an', 'word': 'relations', 'uwingi': 'ahli'},
#  {'neno': 'ahli',
#   'tag': 'noun 9/10an',
#   'word': '\x01distant)',
#   'uwingi': 'ahli'},
#  {'neno': 'and', 'tag': 'other', 'word': '', 'uwingi': ''},
#  {'neno': 'ahli', 'tag': 'noun 9/10an', 'word': 'wife', 'uwingi': 'ahli'},
#  {'neno': 'ahsante', 'tag': 'noun 10', 'word': 'thanks', 'uwingi': ''},
#  {'neno': 'ahsante', 'tag': 'phrase', 'word': 'thank you', 'uwingi': ''},
#  {'neno': 'aibika', 'tag': 'verb', 'word': 'be abashed', 'uwingi': ''},
#  {'neno': 'aibika', 'tag': 'verb', 'word': 'be ashamed', 'uwingi': ''},
#  {'neno': 'aibika', 'tag': 'verb', 'word': 'be disgraced', 'uwingi': ''},
#  {'neno': 'aibika', 'tag': 'verb', 'word': 'be dishonored', 'uwingi': ''},
#  {'neno': 'aibika', 'tag': 'verb', 'word': 'be embarrassed', 'uwingi': ''},
#  {'neno': 'aibisha', 'tag': 'verb causative', 'word': 'abash', 'uwingi': ''},
#  {'neno': 'aibisha',
#   'tag': 'verb causative',
#   'word': 'disconcert',
#   'uwingi': ''},
#  {'neno': 'aibisha',
#   'tag': 'verb causative',
#   'word': 'disgrace',
#   'uwingi': ''},
#  {'neno': 'aibisha',
#   'tag': 'verb causative',
#   'word': 'dishonor',
#   'uwingi': ''},
#  {'neno': 'aibisha',
#   'tag': 'verb causative',
#   'word': 'embarrass',
#   'uwingi': ''},
#  {'neno': 'aibisha',
#   'tag': 'verb causative',
#   'word': 'humiliate',
#   'uwingi': ''},
#  {'neno': 'aibisha', 'tag': 'verb causative', 'word': 'shame', 'uwingi': ''},
#  {'neno': 'aibisho',
#   'tag': 'noun 5/6',
#   'word': 'disgrace',
#   'uwingi': 'maaibisho'},
#  {'neno': 'aibisho',
#   'tag': 'noun 5/6',
#   'word': 'dishonor',
#   'uwingi': 'maaibisho'},
#  {'neno': 'aibisho',
#   'tag': 'noun 5/6',
#   'word': 'embarassment',
#   'uwingi': 'maaibisho'},
#  {'neno': 'aibisho',
#   'tag': 'noun 5/6',
#   'word': 'humiliation',
#   'uwingi': 'maaibisho'},
#  {'neno': 'aibisho',
#   'tag': 'noun 5/6',
#   'word': 'scandal',
#   'uwingi': 'maaibisho'},
#  {'neno': 'aibisho',
#   'tag': 'noun 5/6',
#   'word': 'shame',
#   'uwingi': 'maaibisho'},
#  {'neno': 'aibu', 'tag': 'noun 9/10', 'word': 'disgrace', 'uwingi': 'aibu'},
#  {'neno': 'aibu', 'tag': 'noun 9/10', 'word': 'dishonor', 'uwingi': 'aibu'},
#  {'neno': 'aibu',
#   'tag': 'noun 9/10',
#   'word': 'embarassment',
#   'uwingi': 'aibu'},
#  {'neno': 'aibu', 'tag': 'noun 9/10', 'word': 'humiliation', 'uwingi': 'aibu'},
#  {'neno': 'aibu', 'tag': 'noun 9/10', 'word': 'scandal', 'uwingi': 'aibu'},
#  {'neno': 'aibu', 'tag': 'noun 9/10', 'word': 'shame', 'uwingi': 'aibu'},
#  {'neno': 'aidha', 'tag': 'adverb', 'word': 'furthermore', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'adverb', 'word': 'next', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'conjunction', 'word': 'and', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'conjunction', 'word': 'besides', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'conjunction', 'word': 'further', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'conjunction', 'word': 'moreover', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'conjunction', 'word': 'or', 'uwingi': ''},
#  {'neno': 'aidha', 'tag': 'conjunction', 'word': 'then', 'uwingi': ''},
# ...
#  {'neno': 'akiba', 'tag': 'noun 9/10', 'word': 'savings', 'uwingi': 'akiba'},
#  {'neno': 'akiba', 'tag': 'noun 9/10', 'word': 'stock', 'uwingi': 'akiba'},
#  {'neno': 'akiba',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01tore',
#   'uwingi': 'akiba'},
#  {'neno': 'akiba', 'tag': 'noun 9/10', 'word': 'supply', 'uwingi': 'akiba'},
#  {'neno': 'haiozi',
#   'tag': 'phrase',
#   'word': 'what is saved does not spoil',
#   'uwingi': ''},
#  {'neno': 'wananchi',
#   'tag': 'noun 9/10',
#   'word': '\x01ond',
#   'uwingi': 'akiba'},
#  {'neno': 'akiba', 'tag': 'noun 7/8', 'word': '\x01art', 'uwingi': 'vyombo'},
#  {'neno': 'akida',
#   'tag': 'noun 5/6an',
#   'word': 'adjutant',
#   'uwingi': 'maakida'},
#  {'neno': 'akida', 'tag': 'noun 5/6an', 'word': 'chief', 'uwingi': 'maakida'},
#  {'neno': 'akida',
#   'tag': 'noun 5/6an',
#   'word': 'foreman',
#   'uwingi': 'maakida'},
#  {'neno': 'akida', 'tag': 'noun 5/6an', 'word': 'leader', 'uwingi': 'maakida'},
#  {'neno': 'akida',
#   'tag': 'noun 5/6an',
#   'word': 'manager',
#   'uwingi': 'maakida'},
#  {'neno': 'akida',
#   'tag': 'noun 5/6an',
#   'word': 'officer',
#   'uwingi': 'maakida'},
#  {'neno': 'akida',
#   'tag': 'noun 5/6an',
#   'word': 'supervisor',
#   'uwingi': 'maakida'},
#  {'neno': 'akidi', 'tag': 'verb', 'word': 'conclude', 'uwingi': ''},
#  {'neno': 'akidi', 'tag': 'verb', 'word': 'end', 'uwingi': ''},
#  {'neno': 'akidi', 'tag': 'verb', 'word': 'finish', 'uwingi': ''},
#  {'neno': 'akidi', 'tag': 'verb', 'word': 'suffice', 'uwingi': ''},
#  {'neno': 'akidu',
#   'tag': 'noun 5/6an',
#   'word': 'contractor',
#   'uwingi': 'maakidu'},
#  {'neno': 'akifia',
#   'tag': 'verb',
#   'word': 'entrust with (a task or money or property)',
#   'uwingi': ''},
#  {'neno': 'akifu', 'tag': 'verb', 'word': 'curb', 'uwingi': ''},
#  {'neno': 'akifu', 'tag': 'verb', 'word': 'have a fixed price', 'uwingi': ''},
#  {'neno': 'akifu', 'tag': 'verb', 'word': 'refuse', 'uwingi': ''},
#  {'neno': 'akifu', 'tag': 'verb', 'word': 'reject', 'uwingi': ''},
#  {'neno': 'akifu', 'tag': 'verb', 'word': 'stop', 'uwingi': ''},
#  {'neno': 'akika',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01 child',
#   'uwingi': 'akika'},
#  {'neno': 'akika',
#   'tag': 'noun 9/10',
#   'word': "\x01\x01 baby'\x01\x01aircut",
#   'uwingi': 'akika'},
#  {'neno': 'akiki',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01 child',
#   'uwingi': 'akiki'},
#  {'neno': 'akiki', 'tag': 'noun 9/10', 'word': 'carnelian', 'uwingi': 'akiki'},
#  {'neno': 'akiki',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01 \x01\x01\x01\x01\x01\x01\x01aircutting',
#   'uwingi': 'akiki'},
#  {'neno': 'akili', 'tag': 'verb', 'word': 'consider', 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'verb', 'word': 'reflect', 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'verb', 'word': "broaden one's mind", 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'verb', 'word': 'become agitated', 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'verb', 'word': "lose one's senses", 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'verb', 'word': 'make mentally ill', 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'verb', 'word': 'be mentally ill', 'uwingi': ''},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'ability', 'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'capability',
#   'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'cleverness',
#   'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'competence',
#   'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'discretion',
#   'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'intellect', 'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'intelligence',
#   'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'judgment', 'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'knowledge', 'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'mind', 'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'plan', 'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'proficiency',
#   'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'reason', 'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'sense', 'uwingi': 'akili'},
#  {'neno': 'akili', 'tag': 'noun 9/10', 'word': 'thought', 'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01 \x01ense)',
#   'uwingi': 'akili'},
#  {'neno': 'akili',
#   'tag': 'noun 9/10',
#   'word': 'understanding',
#   'uwingi': 'akili'},
#  {'neno': 'mali',
#   'tag': 'phrase',
#   'word': '(good) sense is wealth',
#   'uwingi': ''},
#  {'neno': 'timamu', 'tag': 'phrase', 'word': 'sound mind', 'uwingi': ''},
#  {'neno': 'akina',
#   'tag': 'adjective',
#   'word': 'person or people like',
#   'uwingi': ''},
#  {'neno': 'akina', 'tag': 'noun 9/10', 'word': 'descent', 'uwingi': 'akina'},
#  {'neno': 'akina',
#   'tag': 'noun 9/10',
#   'word': 'extraction',
#   'uwingi': 'akina'},
#  {'neno': 'akina', 'tag': 'noun 9/10', 'word': 'family', 'uwingi': 'akina'},
#  {'neno': 'akina',
#   'tag': 'noun 9/10an',
#   'word': '\x01\x01o',
#   'uwingi': 'akina'},
#  {'neno': 'mama',
#   'tag': 'noun 9/10an',
#   'word': 'womenfolk',
#   'uwingi': 'akina'},
#  {'neno': 'sisi', 'tag': 'phrase', 'word': '\x01\x01s', 'uwingi': 'akina'},
#  {'neno': 'akisha', 'tag': 'verb', 'word': 'cause to be built', 'uwingi': ''},
#  {'neno': 'akisi', 'tag': 'verb', 'word': 'reflect', 'uwingi': ''},
#  {'neno': 'ako', 'tag': 'pronoun', 'word': 'your (sing)', 'uwingi': ''},
#  {'neno': 'ako', 'tag': 'pronoun', 'word': 'yours (sing)', 'uwingi': ''},
#  {'neno': 'magharibi', 'tag': 'noun', 'word': 'pl sing', 'uwingi': ''},
#  {'neno': 'matlai', 'tag': 'noun', 'word': 'pl sing', 'uwingi': ''},
#  {'neno': 'akraba',
#   'tag': 'noun 9/10an',
#   'word': 'relation',
#   'uwingi': 'akraba'},
#  {'neno': 'akraba',
#   'tag': 'noun 9/10an',
#   'word': '\x01\x01\x01\x01\x01egree)',
#   'uwingi': 'akraba'},
#  {'neno': 'akrabu', 'tag': 'noun', 'word': 'hand', 'uwingi': 'akrabu'},
#  {'neno': 'akrabu', 'tag': 'noun', 'word': 'indicator', 'uwingi': 'akrabu'},
#  {'neno': 'akrabu', 'tag': 'noun', 'word': 'pointer', 'uwingi': 'akrabu'},
#  {'neno': 'aksante', 'tag': 'noun 10', 'word': 'thanks', 'uwingi': ''},
#  {'neno': 'aksante', 'tag': 'phrase', 'word': 'thank you', 'uwingi': ''},
#  {'neno': 'aksidenti',
#   'tag': 'noun 9/10',
#   'word': 'accident',
#   'uwingi': 'aksidenti'},
#  {'neno': 'aktari', 'tag': 'noun 9/10', 'word': 'crowd', 'uwingi': 'aktari'},
#  {'neno': 'aktari',
#   'tag': 'noun 9/10',
#   'word': 'gathering',
#   'uwingi': 'aktari'},
#  {'neno': 'akwe', 'tag': 'pronoun', 'word': 'pl sing', 'uwingi': ''},
#  {'neno': 'akwe', 'tag': 'pronoun', 'word': 'pl sing', 'uwingi': ''},
#  {'neno': 'also', 'tag': 'usually', 'word': '', 'uwingi': ''},
#  {'neno': 'ala',
#   'tag': 'interjection',
#   'word': 'expresses impatience',
#   'uwingi': ''},
#  {'neno': 'ala',
#   'tag': 'interjection',
#   'word': 'expresses amazement',
#   'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'ala', 'tag': 'noun 9/10', 'word': '', 'uwingi': ''},
#  {'neno': 'hali', 'tag': 'conjunction', 'word': 'anyhow', 'uwingi': ''},
#  {'neno': 'hali', 'tag': 'conjunction', 'word': 'anyway', 'uwingi': ''},
#  {'neno': 'muziki', 'tag': 'phrase', 'word': '\x01nstrument', 'uwingi': 'ala'},
#  {'neno': 'alaf', 'tag': 'adjective', 'word': 'thousand', 'uwingi': ''},
#  {'neno': 'alafu', 'tag': 'adjective', 'word': 'thousand', 'uwingi': ''},
#  {'neno': 'alafu', 'tag': 'adverb', 'word': 'afterwards', 'uwingi': ''},
#  {'neno': 'alafu', 'tag': 'adverb', 'word': 'in future', 'uwingi': ''},
#  {'neno': 'alafu', 'tag': 'adverb', 'word': 'later', 'uwingi': ''},
#  {'neno': 'alafu', 'tag': 'adverb', 'word': 'subsequently', 'uwingi': ''},
#  {'neno': 'alafu', 'tag': 'conjunction', 'word': 'then', 'uwingi': ''},
#  {'neno': 'alama', 'tag': 'noun 9/10', 'word': 'grade', 'uwingi': 'alama'},
#  {'neno': 'alama',
#   'tag': 'noun 9/10',
#   'word': 'indication',
#   'uwingi': 'alama'},
#  {'neno': 'alama', 'tag': 'noun 9/10', 'word': 'mark', 'uwingi': 'alama'},
#  {'neno': 'alama', 'tag': 'noun 9/10', 'word': 'postmark', 'uwingi': 'alama'},
#  {'neno': 'alama', 'tag': 'noun 9/10', 'word': 'sign', 'uwingi': 'alama'},
#  {'neno': 'alama', 'tag': 'noun 9/10', 'word': 'symbol', 'uwingi': 'alama'},
#  {'neno': 'alama', 'tag': 'noun 9/10', 'word': 'trace', 'uwingi': 'alama'},
#  {'neno': 'usawa', 'tag': 'noun 9/10', 'word': '\x01ign', 'uwingi': 'alama'},
#  {'neno': 'alamsiki', 'tag': 'interjection', 'word': 'farewell', 'uwingi': ''},
#  {'neno': 'alamsiki', 'tag': 'interjection', 'word': 'good bye', 'uwingi': ''},
#  {'neno': 'alamu', 'tag': 'noun 9/10', 'word': 'banner', 'uwingi': 'alamu'},
#  {'neno': 'alamu', 'tag': 'noun 9/10', 'word': 'flag', 'uwingi': 'alamu'},
#  {'neno': 'alamu', 'tag': 'noun 9/10', 'word': '\x01lag', 'uwingi': 'alamu'},
#  {'neno': 'alamu', 'tag': 'noun 9/10', 'word': 'warning', 'uwingi': 'alamu'},
#  {'neno': 'alasiri',
#   'tag': 'noun 9/10',
#   'word': 'afternoon',
#   'uwingi': 'alasiri'},
#  {'neno': 'alasiri',
#   'tag': 'noun 9/10',
#   'word': 'midafternoon',
#   'uwingi': 'alasiri'},
#  {'neno': 'alasiri',
#   'tag': 'noun 9/10',
#   'word': "\x01\x01 \x01 o'clock)",
#   'uwingi': 'alasiri'},
#  {'neno': 'alau', 'tag': 'adverb', 'word': 'at any rate', 'uwingi': ''},
#  {'neno': 'alau', 'tag': 'adverb', 'word': 'anyhow', 'uwingi': ''},
#  {'neno': 'alau', 'tag': 'adverb', 'word': 'at last', 'uwingi': ''},
#  {'neno': 'alau', 'tag': 'adverb', 'word': 'even', 'uwingi': ''},
#  {'neno': 'alau', 'tag': 'conjunction', 'word': 'although', 'uwingi': ''},
#  {'neno': 'alfabeti',
#   'tag': 'noun 9/10',
#   'word': 'alphabet',
#   'uwingi': 'alfabeti'},
#  {'neno': 'alfafa',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01\x01\x01\x01ound',
#   'uwingi': 'alfafa'},
#  {'neno': 'alfajiri',
#   'tag': 'noun 9/10',
#   'word': 'dawn',
#   'uwingi': 'alfajiri'},
#  {'neno': 'alfajiri',
#   'tag': 'noun 9/10',
#   'word': 'daybreak',
#   'uwingi': 'alfajiri'},
#  {'neno': 'alfajiri',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01 AM)',
#   'uwingi': 'alfajiri'},
#  {'neno': 'alfala',
#   'tag': 'noun 9/10',
#   'word': '\x01\x01\x01\x01\x01\x01\x01ound',
#   'uwingi': 'alfala'},
#  {'neno': 'alfu', 'tag': 'adjective', 'word': 'thousand', 'uwingi': ''},
#  {'neno': 'Alhamisi',
#   'tag': 'noun 9/10',
#   'word': 'Thursday',
#   'uwingi': 'alhamisi'},
#  {'neno': 'kuu', 'tag': 'noun', 'word': 'Maundy Thursday', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'consequently', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'hence', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'similarly', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'then', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'thereupon', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'in this way', 'uwingi': ''},
#  {'neno': 'alhasil', 'tag': 'adverb', 'word': 'thus', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'consequently', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'hence', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'similarly', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'then', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'thereupon', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'in this way', 'uwingi': ''},
#  {'neno': 'alhasir', 'tag': 'adverb', 'word': 'thus', 'uwingi': ''},
#  {'neno': 'alia',
#   'tag': 'verb',
#   'word': 'make marks on the body (by a blow)',
#   'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'beckon', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'call', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'challenge', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'click', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'communicate', 'uwingi': ''},
#  {'neno': 'alika',
#   'tag': 'verb',
#   'word': 'confine (a sick person etc',
#   'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'crack', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'crackle', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'entice', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'explain', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'explode (of bombs)', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'go off (of bombs)', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'inform', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'intern', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'invite', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'ripple (of water)', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'splash', 'uwingi': ''},
#  {'neno': 'alika', 'tag': 'verb', 'word': 'summon', 'uwingi': ''},
#  {'neno': 'alikana', 'tag': 'verb', 'word': 'invite each other', 'uwingi': ''},
#  {'neno': 'aliki', 'tag': 'verb', 'word': 'attach', 'uwingi': ''},
#  {'neno': 'aliki', 'tag': 'verb', 'word': 'fasten', 'uwingi': ''},
#  {'neno': 'aliki', 'tag': 'verb', 'word': 'hang', 'uwingi': ''},
#  {'neno': 'aliki', 'tag': 'verb', 'word': 'hang up', 'uwingi': ''},
#  {'neno': 'aliko', 'tag': 'noun 5/6', 'word': 'call', 'uwingi': 'maaliko'},
#  {'neno': 'aliko',
#   'tag': 'noun 5/6',
#   'word': 'challenge',
#   'uwingi': 'maaliko'},
#  {'neno': 'aliko', 'tag': 'noun 5/6', 'word': 'clapping', 'uwingi': 'maaliko'},
#  {'neno': 'aliko',
#   'tag': 'noun 5/6',
#   'word': '\x01noise)',
#   'uwingi': 'maaliko'},
#  {'neno': 'aliko',
#   'tag': 'noun 5/6',
#   'word': 'invitation',
#   'uwingi': 'maaliko'},
#  {'neno': 'aliko',
#   'tag': 'noun 5/6',
#   'word': '\x01\x01\x01ingers',
#   'uwingi': 'maaliko'},
#  {'neno': 'aliko', 'tag': 'noun 5/6', 'word': 'summons', 'uwingi': 'maaliko'},
#  {'neno': 'alili', 'tag': 'adverb', 'word': 'very', 'uwingi': ''},
#  {'neno': 'alimradhi',
#   'tag': 'conjunction',
#   'word': 'accordingly',
#   'uwingi': ''},
#  {'neno': 'alimradhi', 'tag': 'conjunction', 'word': 'hence', 'uwingi': ''},
#  {'neno': 'alimradhi', 'tag': 'conjunction', 'word': 'and so', 'uwingi': ''},
#  {'neno': 'alimradhi', 'tag': 'conjunction', 'word': 'and then', 'uwingi': ''},
#  {'neno': 'alimradhi',
#   'tag': 'conjunction',
#   'word': 'therefore',
#   'uwingi': ''},
#  {'neno': 'alimradi',
#   'tag': 'conjunction',
#   'word': 'accordingly',
#   'uwingi': ''},
#  {'neno': 'alimradi', 'tag': 'conjunction', 'word': 'hence', 'uwingi': ''},
#  {'neno': 'alimradi', 'tag': 'conjunction', 'word': 'and so', 'uwingi': ''},
#  {'neno': 'alimradi', 'tag': 'conjunction', 'word': 'and then', 'uwingi': ''},
#  {'neno': 'alimradi', 'tag': 'conjunction', 'word': 'therefore', 'uwingi': ''},
#  {'neno': 'alisa', 'tag': 'noun', 'word': '\x01lace', 'uwingi': 'alisa'},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'click', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'cause to crack', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'cause to explode', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'cause (a bomb etc', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'invite', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'cause to ripple', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'cause to snap', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'cause to splash', 'uwingi': ''},
#  {'neno': 'alisha', 'tag': 'verb', 'word': 'summon', 'uwingi': ''},
#  {'neno': 'Allah', 'tag': 'noun 1', 'word': 'God (Moslem)', 'uwingi': ''},
#  {'neno': 'almari',
#   'tag': 'noun',
#   'word': '\x01\x01rawers',
#   'uwingi': 'almari'},
#  {'neno': 'almaria', 'tag': 'verb', 'word': 'braid', 'uwingi': 'almaria'},
#  {'neno': 'almaria', 'tag': 'noun', 'word': 'braids', 'uwingi': 'almaria'},
#  ...]

# %%
df = pd.DataFrame(data=neno_word_trans_dictionary)
df
# Out:
#            neno             tag uwingi                                    word
# 0             a     preposition         of (a + noun used to form possessives)
# 1             a     preposition          of (a + noun used to form adjectives)
# 2             a    interjection                                  expresses joy
# 3             a    interjection                                 expresses pain
# 4             a    interjection                             expresses surprise
# 5            aa    interjection                                  expresses joy
# 6            aa    interjection                                 expresses pain
# 7            aa    interjection                             expresses surprise
# 8          aali       adjective                                      excellent
# 9          aali       adjective                                     firstclass
# 10         aali       adjective                                           good
# 11         aasi            verb                                 be disobedient
# 12         aasi            verb                         not meet an obligation
# 13         aasi            verb                                          rebel
# 14         aasi            verb                                         revolt
# 15         aasi        noun 5/6  maasi                               rebellion
# 16         aasi        noun 5/6  maasi                                  revolt
# 17       abadan          adverb                                          never
# 18       abadan    interjection                                      Make way!
# 19        abadi          adverb                                         always
# 20        abadi          adverb                                     constantly
# 21          abd     noun 9/10an    abd                                 servant
# 22          abd     noun 9/10an    abd                                   slave
# 23     Abdallah            noun                                       Abdullah
# 24          abe    interjection                               At your service!
# 25          abe    interjection                                     Yes ma'am!
# 26          abe    interjection                                       Yes sir!
# 27      abedari    interjection                                      Look out!
# 28      abedari    interjection                                     Take care!
# 29      abedari    interjection                                     Watch out!
# ...         ...             ...    ...                                     ...
# 57829     zusha            verb                                         invent
# 57830     zusha            verb                        make up and spread lies
# 57831     zusha            verb                             produce (suddenly)
# 57832     zusha            verb                             think up something
# 57833    zushia  verb  applcaus                                provoke someone
# 57834    zushia   verb applcaus                                      give rise
# 57835     zuwia            verb                                          check
# 57836     zuwia            verb                                         detain
# 57837     zuwia            verb                                          deter
# 57838     zuwia            verb                                         hinder
# 57839     zuwia            verb                                      hold back
# 57840     zuwia            verb                                          limit
# 57841     zuwia            verb                                        prevent
# 57842     zuwia            verb                                        protect
# 57843     zuwia            verb                                       restrain
# 57844     zuwia            verb                                        support
# 57845     zuwia            verb                                       withhold
# 57846      zuzu       adjective                                        foolish
# 57847      zuzu       adjective                                         stupid
# 57848      zuzu       adjective                                       ignorant
# 57849      zuzu       adjective                                  inexperienced
# 57850     zuzua            verb                                      embarrass
# 57851     zuzua            verb                                 make a fool of
# 57852     zuzua            verb                           treat as a simpleton
# 57853     zuzua            verb                         play tricks on someone
# 57854    zuzuka            verb                                   be at a loss
# 57855    zuzuka            verb                                    be confused
# 57856    zuzuka            verb                                    be deceived
# 57857    zuzuka            verb                                      be fooled
# 57858   zuzulia            verb                                           appl
#
# [57859 rows x 4 columns]

# %%
df.
